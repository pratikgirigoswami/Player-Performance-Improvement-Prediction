# %% [markdown]
# ## Install the packages

# %%
# %pip install nba_api
# %pip install pandas

# %% [markdown]
# ## Import the libraries

# %%
import pandas as pd
import time

from nba_api.stats.static import players
from nba_api.stats.static import teams
from nba_api.stats.endpoints import playergamelog
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.endpoints import playernextngames
from nba_api.stats.endpoints import commonplayerinfo

# %% [markdown]
# ## Basic search parameters

# %%
# season = '2020-21'
# season = '2019-20'
season = '2021-22'
season_type = 'Regular Season'

# %% [markdown]
# ## Get active players IDs

# %%
active_players = players.get_active_players()
active_players[0:2]
# Out:
# [{'id': 1630173,
#   'full_name': 'Precious Achiuwa',
#   'first_name': 'Precious',
#   'last_name': 'Achiuwa',
#   'is_active': True},
#  {'id': 203500,
#   'full_name': 'Steven Adams',
#   'first_name': 'Steven',
#   'last_name': 'Adams',
#   'is_active': True}]

# %%
players_ids = [str(player['id']) for player in active_players]
players_ids[0:2]
# Out:
# ['1630173', '203500']

# %%
len(players_ids)
# Out:
# 587

# %% [markdown]
# ## Get teams IDs

# %%
nba_teams_full_info = teams.get_teams()
nba_teams_full_info[:2]
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946}]

# %%
nba_teams_short_info = [{'id': team['id'], 'full_name': team['full_name'], 'abbreviation': team['abbreviation']} for team in nba_teams_full_info]
nba_teams_short_info[0:2]
# Out:
# [{'id': 1610612737, 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL'},
#  {'id': 1610612738, 'full_name': 'Boston Celtics', 'abbreviation': 'BOS'}]

# %%
nba_teams_ids = [team['id'] for team in nba_teams_full_info]
nba_teams_ids[0:2]
# Out:
# [1610612737, 1610612738]

# %% [markdown]
# ## Get stats by game (player total)

# %%
columns = ['SEASON_ID', 'Player_ID', 'Game_ID', 'GAME_DATE', 'MATCHUP', 'WL',
       'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
       'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
       'PTS', 'PLUS_MINUS', 'VIDEO_AVAILABLE']

df = pd.DataFrame(columns=columns)

# %%
for idx, id in enumerate(players_ids):
    try:
        data = playergamelog.PlayerGameLog(
            player_id=id,
            season=season,
            season_type_all_star=season_type,
            league_id_nullable='00',
            timeout=10)
    
        df = pd.concat([df, data.get_data_frames()[0]])
        
        # Preventing timeout exceptions
        time.sleep(.600)
    except:
        print(f'There was some problem while gathering data.\nPlayer id: {id}\nIteration #{idx}\n')

df.head(3)
# Out:
#   SEASON_ID Player_ID     Game_ID     GAME_DATE      MATCHUP WL MIN FGM FGA  \
# 0     22021   1630173  0022101095  MAR 24, 2022  TOR vs. CLE  W  22   3  10
# 1     22021   1630173  0022101076  MAR 21, 2022    TOR @ CHI  L  28   3   9
# 2     22021   1630173  0022101069  MAR 20, 2022    TOR @ PHI  W  34   9  15
#
#   FG_PCT  ... DREB REB AST STL BLK TOV PF PTS PLUS_MINUS VIDEO_AVAILABLE
# 0    0.3  ...    4   4   1   0   0   0  2  10          8               1
# 1  0.333  ...    8   9   1   0   0   1  1   6        -11               1
# 2    0.6  ...    4   9   1   0   0   0  4  21          7               1
#
# [3 rows x 27 columns]

# %%
df.shape
# Out:
# (22803, 27)

# %%
print(f"The final dataset contais stats about {df['Player_ID'].nunique()} players")
# Out:
# The final dataset contais stats about 535 players

# %%
df_2021_22 = df.copy()

# %% [markdown]
# This difference in relation to the length of players_ids is acceptable, due various reasons, like the players who dont play any game during the season, or players who got hurt in the pre-season.

# %% [markdown]
# ## Save the DataFrame

# %% [markdown]
# ### 2020-21

# %%
# Pickle
df.to_pickle('df_2021_22.pkl')

# Unpickle
# df_2020_21 = pd.read_pickle('Datasets/df_all_players_raw.pkl')

# %% [markdown]
# The original name of df_2020_21 was df_all_players_raw (and the pickle file was named df_all_player_raw.pkl). This name was replaced because it was confusing.

# %% [markdown]
# ### 2020-21

# %%
import pickle
import pandas as pd

# Renaming the dataframe from 2020-21
# Get the data from the previous file
# df_2020_21 = pd.read_pickle('Datasets/df_all_players_raw.pkl')

# Saving with the new name
# with open('Datasets/df_2020_21.pkl', 'wb') as f:
    # pickle.dump(df_2020_21, f)

# Unpickle
with open('Datasets/df_2020_21.pkl', 'rb') as f:
    df_2020_21 = pickle.load(f)

# %% [markdown]
# ### 2019-20

# %%
import pickle
import pandas as pd

# Pickle
# with open('Datasets/df_2019_20.pkl', 'wb') as f:
    # pickle.dump(df_2019_20, f)

# Unpickle
with open('Datasets/df_2019_20.pkl', 'rb') as f:
    df_2019_20 = pickle.load(f)

# %% [markdown]
# ### 2018-19

# %%
import pickle
import pandas as pd

# Pickle
# with open('Datasets/df_2018_19.pkl', 'wb') as f:
    # pickle.dump(df_2018_19, f)

# Unpickle
with open('Datasets/df_2018_19.pkl', 'rb') as f:
    df_2018_19 = pickle.load(f)

# %% [markdown]
# ### Join the datasets

# %%
print(f'Shape of 2018-19 dataset: {df_2018_19.shape}')
print(f'Shape of 2019-20 dataset: {df_2019_20.shape}')
print(f'Shape of 2020-21 dataset: {df_2020_21.shape}')
print(f'Shape of 2021-22 dataset: {df_2021_22.shape}')
# Out:
# Shape of 2018-19 dataset: (18388, 27)
# Shape of 2019-20 dataset: (18416, 27)
# Shape of 2020-21 dataset: (21349, 27)
# Shape of 2021-22 dataset: (22803, 27)

# %%
df = pd.concat([df_2018_19, df_2019_20, df_2020_21, df_2021_22], axis=0, ignore_index=True)
df.head(3)
# Out:
#   SEASON_ID Player_ID     Game_ID     GAME_DATE      MATCHUP WL MIN FGM FGA  \
# 0     22018    203500  0021801226  APR 10, 2019    OKC @ MIL  W  12   1   5
# 1     22018    203500  0021801218  APR 09, 2019  OKC vs. HOU  W  37   3  11
# 2     22018    203500  0021801197  APR 07, 2019    OKC @ MIN  W  27   4   5
#
#   FG_PCT  ... DREB REB AST STL BLK TOV PF PTS PLUS_MINUS VIDEO_AVAILABLE
# 0    0.2  ...    0   2   0   0   1   0  1   4         -1               1
# 1  0.273  ...    5  13   1   0   0   0  1   8          2               1
# 2    0.8  ...    4   6   1   1   0   3  6   8         31               1
#
# [3 rows x 27 columns]

# %%
df.shape
# Out:
# (80956, 27)

# %%
df_2018_19.shape[0] + df_2019_20.shape[0] + df_2020_21.shape[0] + df_2021_22.shape[0]
# Out:
# 80956

# %%
df.isna().sum().sum()
# Out:
# 62

# %%
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df.isna().sum().sum()
# Out:
# 0

# %%
df.head(2)
# Out:
#   SEASON_ID Player_ID     Game_ID     GAME_DATE      MATCHUP WL MIN FGM FGA  \
# 0     22018    203500  0021801226  APR 10, 2019    OKC @ MIL  W  12   1   5
# 1     22018    203500  0021801218  APR 09, 2019  OKC vs. HOU  W  37   3  11
#
#   FG_PCT  ... DREB REB AST STL BLK TOV PF PTS PLUS_MINUS VIDEO_AVAILABLE
# 0    0.2  ...    0   2   0   0   1   0  1   4         -1               1
# 1  0.273  ...    5  13   1   0   0   0  1   8          2               1
#
# [2 rows x 27 columns]

# %% [markdown]
# ### Save the 'final' dataset

# %%
import pickle
import pandas as pd

# Pickle
with open('Datasets/df_2018_to_2022_raw.pkl', 'wb') as f:
    pickle.dump(df, f)

# Unpickle
# with open('Datasets/df_2018_to_2021_raw.pkl', 'rb') as f:
    # df = pickle.load(f)

# %% [markdown]
# ## Adjust the columns names

# %%
df.columns
# Out:
# Index(['SEASON_ID', 'Player_ID', 'Game_ID', 'GAME_DATE', 'MATCHUP', 'WL',
#        'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
#        'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'PLUS_MINUS', 'VIDEO_AVAILABLE'],
#       dtype='object')

# %%
new_column_names = ['Season ID', 'Player ID', 'Game ID', 'Game Date', 'Matchup', 'Won or Lost',
       'Minutes played', 'Field Goals Made', 'Field Goals Attempted', 'Field Goals %', 
       'Field Goals 3 Points Made', 'Field Goal 3 Points Attempt', 'Field Goal 3 Points %', 
       'Free Throws Made', 'Free Throws Attempt', 'Free Throw %', 'Offensive Rebounds', 'Defensive Rebounds', 'Rebounds', 
       'Assists', 'Steals', 'Blocks', 'Turnovers', 'Personal Fouls',
       'Points', 'Plus Minus', 'Video Available']
    
df.columns = new_column_names
df.columns
# Out:
# Index(['Season ID', 'Player ID', 'Game ID', 'Game Date', 'Matchup',
#        'Won or Lost', 'Minutes played', 'Field Goals Made',
#        'Field Goals Attempted', 'Field Goals %', 'Field Goals 3 Points Made',
#        'Field Goal 3 Points Attempt', 'Field Goal 3 Points %',
#        'Free Throws Made', 'Free Throws Attempt', 'Free Throw %',
#        'Offensive Rebounds', 'Defensive Rebounds', 'Rebounds', 'Assists',
#        'Steals', 'Blocks', 'Turnovers', 'Personal Fouls', 'Points',
#        'Plus Minus', 'Video Available'],
#       dtype='object')

# %% [markdown]
# ## Drop the irrelevant features

# %%
columns_to_drop = ['Field Goals %', 'Field Goal 3 Points %', 
'Free Throw %', 'Rebounds', 'Plus Minus', 'Video Available']

df.drop(columns=columns_to_drop, inplace=True)
df.columns
# Out:
# Index(['Season ID', 'Player ID', 'Game ID', 'Game Date', 'Matchup',
#        'Won or Lost', 'Minutes played', 'Field Goals Made',
#        'Field Goals Attempted', 'Field Goals 3 Points Made',
#        'Field Goal 3 Points Attempt', 'Free Throws Made',
#        'Free Throws Attempt', 'Offensive Rebounds', 'Defensive Rebounds',
#        'Assists', 'Steals', 'Blocks', 'Turnovers', 'Personal Fouls', 'Points'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   Season ID Player ID     Game ID     Game Date      Matchup Won or Lost  \
# 0     22018    203500  0021801226  APR 10, 2019    OKC @ MIL           W
# 1     22018    203500  0021801218  APR 09, 2019  OKC vs. HOU           W
#
#   Minutes played Field Goals Made Field Goals Attempted  \
# 0             12                1                     5
# 1             37                3                    11
#
#   Field Goals 3 Points Made  ... Free Throws Made Free Throws Attempt  \
# 0                         0  ...                2                   4
# 1                         0  ...                2                   4
#
#   Offensive Rebounds Defensive Rebounds Assists Steals Blocks Turnovers  \
# 0                  2                  0       0      0      1         0
# 1                  8                  5       1      0      0         0
#
#   Personal Fouls Points
# 0              1      4
# 1              1      8
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Checking the missing values

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Check for duplicated rows

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Reset the index

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Adjust the data types

# %% [markdown]
# ### Adjust Game Date

# %%
df['Game Date'] =  pd.to_datetime(df['Game Date'])
df.head(2)
# Out:
#   Season ID Player ID     Game ID  Game Date      Matchup Won or Lost  \
# 0     22018    203500  0021801226 2019-04-10    OKC @ MIL           W
# 1     22018    203500  0021801218 2019-04-09  OKC vs. HOU           W
#
#   Minutes played Field Goals Made Field Goals Attempted  \
# 0             12                1                     5
# 1             37                3                    11
#
#   Field Goals 3 Points Made  ... Free Throws Made Free Throws Attempt  \
# 0                         0  ...                2                   4
# 1                         0  ...                2                   4
#
#   Offensive Rebounds Defensive Rebounds Assists Steals Blocks Turnovers  \
# 0                  2                  0       0      0      1         0
# 1                  8                  5       1      0      0         0
#
#   Personal Fouls Points
# 0              1      4
# 1              1      8
#
# [2 rows x 21 columns]

# %% [markdown]
# ### Adjust Won or Lost

# %%
df['Won or Lost'].replace({'W': 1, 'L': 0}, inplace=True)
df.rename(columns={'Won or Lost': 'Won'}, inplace=True)
df.head(2)
# Out:
#   Season ID Player ID     Game ID  Game Date      Matchup  Won Minutes played  \
# 0     22018    203500  0021801226 2019-04-10    OKC @ MIL    1             12
# 1     22018    203500  0021801218 2019-04-09  OKC vs. HOU    1             37
#
#   Field Goals Made Field Goals Attempted Field Goals 3 Points Made  ...  \
# 0                1                     5                         0  ...
# 1                3                    11                         0  ...
#
#   Free Throws Made Free Throws Attempt Offensive Rebounds Defensive Rebounds  \
# 0                2                   4                  2                  0
# 1                2                   4                  8                  5
#
#   Assists Steals Blocks Turnovers Personal Fouls Points
# 0       0      0      1         0              1      4
# 1       1      0      0         0              1      8
#
# [2 rows x 21 columns]

# %% [markdown]
# ### Adjust the numeric features types

# %%
df.dtypes
# Out:
# Season ID                              object
# Player ID                              object
# Game ID                                object
# Game Date                      datetime64[ns]
# Matchup                                object
# Won                                     int64
# Minutes played                         object
# Field Goals Made                       object
# Field Goals Attempted                  object
# Field Goals 3 Points Made              object
# Field Goal 3 Points Attempt            object
# Free Throws Made                       object
# Free Throws Attempt                    object
# Offensive Rebounds                     object
# Defensive Rebounds                     object
# Assists                                object
# Steals                                 object
# Blocks                                 object
# Turnovers                              object
# Personal Fouls                         object
# Points                                 object
# dtype: object

# %%
columns_to_int = ['Minutes played', 'Field Goals Made', 'Field Goals Attempted',
       'Field Goals 3 Points Made', 'Field Goal 3 Points Attempt',
       'Free Throws Made', 'Free Throws Attempt', 'Offensive Rebounds',
       'Defensive Rebounds', 'Assists', 'Steals', 'Blocks', 'Turnovers',
       'Personal Fouls', 'Points']

columns_to_str = ['Season ID', 'Player ID', 'Game ID', 'Matchup']

# %%
df[columns_to_int] = df[columns_to_int].apply(pd.to_numeric)
df[columns_to_str] = df[columns_to_str].apply(lambda x: x.astype(str))
df.dtypes
# Out:
# Season ID                              object
# Player ID                              object
# Game ID                                object
# Game Date                      datetime64[ns]
# Matchup                                object
# Won                                     int64
# Minutes played                          int64
# Field Goals Made                        int64
# Field Goals Attempted                   int64
# Field Goals 3 Points Made               int64
# Field Goal 3 Points Attempt             int64
# Free Throws Made                        int64
# Free Throws Attempt                     int64
# Offensive Rebounds                      int64
# Defensive Rebounds                      int64
# Assists                                 int64
# Steals                                  int64
# Blocks                                  int64
# Turnovers                               int64
# Personal Fouls                          int64
# Points                                  int64
# dtype: object

# %%
df.head(2)
# Out:
#   Season ID Player ID     Game ID  Game Date      Matchup  Won  \
# 0     22018    203500  0021801226 2019-04-10    OKC @ MIL    1
# 1     22018    203500  0021801218 2019-04-09  OKC vs. HOU    1
#
#    Minutes played  Field Goals Made  Field Goals Attempted  \
# 0              12                 1                      5
# 1              37                 3                     11
#
#    Field Goals 3 Points Made  ...  Free Throws Made  Free Throws Attempt  \
# 0                          0  ...                 2                    4
# 1                          0  ...                 2                    4
#
#    Offensive Rebounds  Defensive Rebounds  Assists  Steals  Blocks  Turnovers  \
# 0                   2                   0        0       0       1          0
# 1                   8                   5        1       0       0          0
#
#    Personal Fouls  Points
# 0               1       4
# 1               1       8
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Include aditional features

# %% [markdown]
# ### Include player name

# %%
players_ids[0:3]
# Out:
# ['1630173', '203500', '1628389']

# %%
active_players[0:2]
# Out:
# [{'id': 1630173,
#   'full_name': 'Precious Achiuwa',
#   'first_name': 'Precious',
#   'last_name': 'Achiuwa',
#   'is_active': True},
#  {'id': 203500,
#   'full_name': 'Steven Adams',
#   'first_name': 'Steven',
#   'last_name': 'Adams',
#   'is_active': True}]

# %%
players_ids.index('203500')
# Out:
# 1

# %%
active_players[players_ids.index('203500')]['full_name']
# Out:
# 'Steven Adams'

# %%
df['Player Name'] = df['Player ID'].apply(lambda x: str(active_players[players_ids.index(str(x))]['full_name']))
df.head(2)
# Out:
#   Season ID Player ID     Game ID  Game Date      Matchup  Won  \
# 0     22018    203500  0021801226 2019-04-10    OKC @ MIL    1
# 1     22018    203500  0021801218 2019-04-09  OKC vs. HOU    1
#
#    Minutes played  Field Goals Made  Field Goals Attempted  \
# 0              12                 1                      5
# 1              37                 3                     11
#
#    Field Goals 3 Points Made  ...  Free Throws Attempt  Offensive Rebounds  \
# 0                          0  ...                    4                   2
# 1                          0  ...                    4                   8
#
#    Defensive Rebounds  Assists  Steals  Blocks  Turnovers  Personal Fouls  \
# 0                   0        0       0       1          0               1
# 1                   5        1       0       0          0               1
#
#    Points   Player Name
# 0       4  Steven Adams
# 1       8  Steven Adams
#
# [2 rows x 22 columns]

# %%
df.tail(2)
# Out:
#       Season ID Player ID     Game ID  Game Date      Matchup  Won  \
# 80892     22021   1627826  0022100034 2021-10-23  LAC vs. MEM    0
# 80893     22021   1627826  0022100016 2021-10-21    LAC @ GSW    0
#
#        Minutes played  Field Goals Made  Field Goals Attempted  \
# 80892              19                 3                      7
# 80893              17                 4                      7
#
#        Field Goals 3 Points Made  ...  Free Throws Attempt  \
# 80892                          0  ...                    0
# 80893                          0  ...                   10
#
#        Offensive Rebounds  Defensive Rebounds  Assists  Steals  Blocks  \
# 80892                   4                   4        3       0       0
# 80893                   1                   2        2       0       0
#
#        Turnovers  Personal Fouls  Points  Player Name
# 80892          0               2       6  Ivica Zubac
# 80893          0               2      14  Ivica Zubac
#
# [2 rows x 22 columns]

# %% [markdown]
# ### Include the players team name

# %% [markdown]
# #### Games

# %% [markdown]
# ##### 2018-19

# %%
season = '2018-19'
game_finder = leaguegamefinder.LeagueGameFinder(season_nullable=season, season_type_nullable=season_type)
games_2018_19 = game_finder.get_data_frames()[0]
games_2018_19.head(2)
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION          TEAM_NAME     GAME_ID  \
# 0     22018  1610612746               LAC        LA Clippers  0021801229
# 1     22018  1610612759               SAS  San Antonio Spurs  0021801227
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2019-04-10  LAC vs. UTA  W  264  143  ...   0.767    12    40   52   34
# 1  2019-04-10  SAS vs. DAL  W  242  105  ...   0.833     8    45   53   22
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    7    5   12  27         6.0
# 1    6    2   10  14        11.0
#
# [2 rows x 28 columns]

# %% [markdown]
# ##### 2019-20

# %%
season = '2019-20'
game_finder = leaguegamefinder.LeagueGameFinder(season_nullable=season, season_type_nullable=season_type)
games_2019_20 = game_finder.get_data_frames()[0]
games_2019_20.head(2)
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 0     22019  1610612748               MIA      Miami Heat  0021901316
# 1     22019  1610612743               DEN  Denver Nuggets  0021901318
#
#     GAME_DATE    MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  STL  \
# 0  2020-08-14  MIA @ IND  L  240   92  ...   0.741    14    34   48   14    6
# 1  2020-08-14  DEN @ TOR  L  240  109  ...   0.913     9    32   41   27    9
#
#    BLK  TOV  PF  PLUS_MINUS
# 0    5   19  15       -17.0
# 1   11   15  15        -8.0
#
# [2 rows x 28 columns]

# %% [markdown]
# ##### 2020-21

# %%
season = '2020-21'
game_finder = leaguegamefinder.LeagueGameFinder(season_nullable=season, season_type_nullable=season_type)
games_2020_21 = game_finder.get_data_frames()[0]
games_2020_21.head(2)
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME     GAME_ID  \
# 0     22020  1610612750               MIN  Minnesota Timberwolves  0022001071
# 1     22020  1610612744               GSW   Golden State Warriors  0022001070
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2021-05-16  MIN vs. DAL  W  241  136  ...   0.840    11    27   38   35
# 1  2021-05-16  GSW vs. MEM  W  240  113  ...   0.889    12    34   46   26
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0   11    4    9  22        15.0
# 1    9    4   19  19        12.0
#
# [2 rows x 28 columns]

# %% [markdown]
# ##### 2021-22

# %%
season = '2021-22'
game_finder = leaguegamefinder.LeagueGameFinder(season_nullable=season, season_type_nullable=season_type)
games_2021_22 = game_finder.get_data_frames()[0]
games_2021_22.head(2)
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION            TEAM_NAME     GAME_ID  \
# 0     22021  1610612765               DET      Detroit Pistons  0022101101
# 1     22021  1612709910               FWN  Fort Wayne Mad Ants  2022100448
#
#     GAME_DATE      MATCHUP    WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2022-03-25  DET vs. WAS  None  145   64  ...   0.917     7    24   31   12
# 1  2022-03-25  FWN vs. MCC  None  179   97  ...   0.667     8    28   36   19
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    4    3   11  14       -16.8
# 1    8    5   16  13        -2.0
#
# [2 rows x 28 columns]

# %% [markdown]
# ##### Join the datasets

# %%
games = pd.concat([games_2018_19, games_2019_20, games_2020_21, games_2021_22], ignore_index=True)
games = games[['SEASON_ID', 'TEAM_ABBREVIATION', 'GAME_ID', 'WL']]
games.head(2)
# Out:
#   SEASON_ID TEAM_ABBREVIATION     GAME_ID WL
# 0     22018               LAC  0021801229  W
# 1     22018               SAS  0021801227  W

# %%
def get_team_name(player_id, game_id):
    if df[(df['Player ID'] == player_id) & (df['Game ID'] == game_id)]['Won'].values[0]:
        return games[(games['GAME_ID'] == game_id) & (games['WL'] == 'W')]['TEAM_ABBREVIATION'].values[0]
    else:
        return games[(games['GAME_ID'] == game_id) & (games['WL'] == 'L')]['TEAM_ABBREVIATION'].values[0]

# %%
# Player ID = 1627826: Ivica Zubac
# Expected return: LAC
get_team_name(player_id='1627826', game_id='0022000002')
# Out:
# 'LAC'

# %%
player_team = []

for idx, row in df.iterrows():
    player_team.append(get_team_name(row['Player ID'], row['Game ID']))

df['Player Team'] = player_team

# %%
df[(df['Player ID'] == '1627826') & (df['Won'] == 0)].head(1)
# Out:
#       Season ID Player ID     Game ID  Game Date    Matchup  Won  \
# 18330     22018   1627826  0021801205 2019-04-07  LAC @ GSW    0
#
#        Minutes played  Field Goals Made  Field Goals Attempted  \
# 18330              21                 2                      8
#
#        Field Goals 3 Points Made  ...  Offensive Rebounds  Defensive Rebounds  \
# 18330                          0  ...                   3                   5
#
#        Assists  Steals  Blocks  Turnovers  Personal Fouls  Points  \
# 18330        1       0       0          0               0       7
#
#        Player Name  Player Team
# 18330  Ivica Zubac          LAC
#
# [1 rows x 23 columns]

# %%
df[df['Player Name'] == 'LeBron James'].head(1)
# Out:
#      Season ID Player ID     Game ID  Game Date      Matchup  Won  \
# 9511     22018      2544  0021801135 2019-03-29  LAL vs. CHA    1
#
#       Minutes played  Field Goals Made  Field Goals Attempted  \
# 9511              32                11                     19
#
#       Field Goals 3 Points Made  ...  Offensive Rebounds  Defensive Rebounds  \
# 9511                          4  ...                   0                   3
#
#       Assists  Steals  Blocks  Turnovers  Personal Fouls  Points  \
# 9511        9       0       0          6               1      27
#
#        Player Name  Player Team
# 9511  LeBron James          LAL
#
# [1 rows x 23 columns]

# %% [markdown]
# ### Include Home x Away

# %%
df[df['Game ID'] == '0022001072']
# Out:
#       Season ID Player ID     Game ID  Game Date      Matchup  Won  \
# 37013     22020   1629638  0022001072 2021-05-16  NOP vs. LAL    0
# 39035     22020    202339  0022001072 2021-05-16  NOP vs. LAL    0
# 40412     22020    203484  0022001072 2021-05-16    LAL @ NOP    1
# 40812     22020   1627936  0022001072 2021-05-16    LAL @ NOP    1
# 41722     22020    203076  0022001072 2021-05-16    LAL @ NOP    1
# 42364     22020    203083  0022001072 2021-05-16    LAL @ NOP    1
# 43146     22020   1629117  0022001072 2021-05-16  NOP vs. LAL    0
# 45011     22020   1629637  0022001072 2021-05-16  NOP vs. LAL    0
# 45193     22020   1626195  0022001072 2021-05-16  NOP vs. LAL    0
# 45828     22020   1629659  0022001072 2021-05-16    LAL @ NOP    1
# 46677     22020      2544  0022001072 2021-05-16    LAL @ NOP    1
# 46874     22020    201949  0022001072 2021-05-16  NOP vs. LAL    0
# 47901     22020   1628398  0022001072 2021-05-16    LAL @ NOP    1
# 48418     22020   1630184  0022001072 2021-05-16  NOP vs. LAL    0
# 48789     22020   1629712  0022001072 2021-05-16  NOP vs. LAL    0
# 49160     22020   1630230  0022001072 2021-05-16  NOP vs. LAL    0
# 49958     22020    203463  0022001072 2021-05-16    LAL @ NOP    1
# 54474     22020    203471  0022001072 2021-05-16    LAL @ NOP    1
#
#        Minutes played  Field Goals Made  Field Goals Attempted  \
# 37013              37                 5                     15
# 39035              22                 5                      9
# 40412              27                 4                      8
# 40812              19                 4                      8
# 41722              30                 5                     12
# 42364              21                 6                     11
# 43146              20                 1                      4
# 45011              20                 4                      7
# 45193              30                 8                     11
# 45828              14                 2                      6
# 46677              27                11                     22
# 46874              26                 4                     11
# 47901              27                 3                      5
# 48418              26                 4                      6
# 48789              19                 0                      2
# 49160              35                 6                     13
# 49958               1                 0                      0
# 54474              29                 5                     11
#
#        Field Goals 3 Points Made  ...  Offensive Rebounds  Defensive Rebounds  \
# 37013                          2  ...                   1                   3
# 39035                          2  ...                   0                   4
# 40412                          2  ...                   0                   1
# 40812                          1  ...                   1                   2
# 41722                          0  ...                   0                   5
# 42364                          0  ...                   5                   8
# 43146                          0  ...                   0                   4
# 45011                          0  ...                   2                   5
# 45193                          0  ...                   4                   9
# 45828                          1  ...                   0                   1
# 46677                          2  ...                   1                   0
# 46874                          0  ...                   1                   3
# 47901                          0  ...                   0                   6
# 48418                          1  ...                   0                   3
# 48789                          0  ...                   0                   1
# 49160                          4  ...                   0                   6
# 49958                          0  ...                   0                   0
# 54474                          2  ...                   0                   3
#
#        Assists  Steals  Blocks  Turnovers  Personal Fouls  Points  \
# 37013        5       1       0          4               0      14
# 39035        2       0       2          0               0      13
# 40412        6       1       0          0               3      10
# 40812        5       0       1          1               2       9
# 41722        1       1       0          1               0      14
# 42364        0       2       2          2               5      13
# 43146        0       0       1          0               6       4
# 45011        3       1       0          0               2      10
# 45193        1       0       2          2               4      19
# 45828        1       2       0          1               1       6
# 46677        6       3       0          2               0      25
# 46874        3       0       0          2               4       8
# 47901        3       0       0          0               0       8
# 48418        4       1       0          2               0      12
# 48789        1       0       0          3               1       0
# 49160        7       1       0          7               1      18
# 49958        0       0       0          0               0       0
# 54474        4       2       0          0               3      12
#
#                     Player Name  Player Team
# 37013  Nickeil Alexander-Walker          NOP
# 39035              Eric Bledsoe          NOP
# 40412  Kentavious Caldwell-Pope          LAL
# 40812               Alex Caruso          LAL
# 41722             Anthony Davis          LAL
# 42364            Andre Drummond          LAL
# 43146            Wenyen Gabriel          NOP
# 45011              Jaxson Hayes          NOP
# 45193         Willy Hernangomez          NOP
# 45828       Talen Horton-Tucker          LAL
# 46677              LeBron James          LAL
# 46874             James Johnson          NOP
# 47901                Kyle Kuzma          LAL
# 48418            Kira Lewis Jr.          NOP
# 48789              Didi Louzada          NOP
# 49160             Naji Marshall          NOP
# 49958              Ben McLemore          LAL
# 54474           Dennis Schroder          LAL
#
# [18 rows x 23 columns]

# %% [markdown]
# #### The '@' in the 'Matchup' feature indicates that the game was in the second location

# %%
df['Home'] = df['Matchup'].apply(lambda x: 0 if x[4] == '@' else 1)

# %%
df[df['Game ID'] == '0022001072'][['Game ID', 'Matchup', 'Player Name', 'Player Team', 'Home']]
# Out:
#           Game ID      Matchup               Player Name Player Team  Home
# 37013  0022001072  NOP vs. LAL  Nickeil Alexander-Walker         NOP     1
# 39035  0022001072  NOP vs. LAL              Eric Bledsoe         NOP     1
# 40412  0022001072    LAL @ NOP  Kentavious Caldwell-Pope         LAL     0
# 40812  0022001072    LAL @ NOP               Alex Caruso         LAL     0
# 41722  0022001072    LAL @ NOP             Anthony Davis         LAL     0
# 42364  0022001072    LAL @ NOP            Andre Drummond         LAL     0
# 43146  0022001072  NOP vs. LAL            Wenyen Gabriel         NOP     1
# 45011  0022001072  NOP vs. LAL              Jaxson Hayes         NOP     1
# 45193  0022001072  NOP vs. LAL         Willy Hernangomez         NOP     1
# 45828  0022001072    LAL @ NOP       Talen Horton-Tucker         LAL     0
# 46677  0022001072    LAL @ NOP              LeBron James         LAL     0
# 46874  0022001072  NOP vs. LAL             James Johnson         NOP     1
# 47901  0022001072    LAL @ NOP                Kyle Kuzma         LAL     0
# 48418  0022001072  NOP vs. LAL            Kira Lewis Jr.         NOP     1
# 48789  0022001072  NOP vs. LAL              Didi Louzada         NOP     1
# 49160  0022001072  NOP vs. LAL             Naji Marshall         NOP     1
# 49958  0022001072    LAL @ NOP              Ben McLemore         LAL     0
# 54474  0022001072    LAL @ NOP           Dennis Schroder         LAL     0

# %% [markdown]
# ### Include opponent

# %%
df['Opponent'] = df['Matchup'].apply(lambda x: x[-3:])
df.head()
# Out:
#   Season ID Player ID     Game ID  Game Date      Matchup  Won  \
# 0     22018    203500  0021801226 2019-04-10    OKC @ MIL    1
# 1     22018    203500  0021801218 2019-04-09  OKC vs. HOU    1
# 2     22018    203500  0021801197 2019-04-07    OKC @ MIN    1
# 3     22018    203500  0021801186 2019-04-05  OKC vs. DET    1
# 4     22018    203500  0021801161 2019-04-02  OKC vs. LAL    1
#
#    Minutes played  Field Goals Made  Field Goals Attempted  \
# 0              12                 1                      5
# 1              37                 3                     11
# 2              27                 4                      5
# 3              24                 7                      9
# 4              33                 6                     11
#
#    Field Goals 3 Points Made  ...  Assists  Steals  Blocks  Turnovers  \
# 0                          0  ...        0       0       1          0
# 1                          0  ...        1       0       0          0
# 2                          0  ...        1       1       0          3
# 3                          0  ...        0       0       2          2
# 4                          0  ...        3       1       5          2
#
#    Personal Fouls  Points   Player Name  Player Team  Home  Opponent
# 0               1       4  Steven Adams          OKC     0       MIL
# 1               1       8  Steven Adams          OKC     1       HOU
# 2               6       8  Steven Adams          OKC     0       MIN
# 3               4      14  Steven Adams          OKC     1       DET
# 4               2      13  Steven Adams          OKC     1       LAL
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Rearrange columns order

# %%
df.columns
# Out:
# Index(['Season ID', 'Player ID', 'Game ID', 'Game Date', 'Matchup', 'Won',
#        'Minutes played', 'Field Goals Made', 'Field Goals Attempted',
#        'Field Goals 3 Points Made', 'Field Goal 3 Points Attempt',
#        'Free Throws Made', 'Free Throws Attempt', 'Offensive Rebounds',
#        'Defensive Rebounds', 'Assists', 'Steals', 'Blocks', 'Turnovers',
#        'Personal Fouls', 'Points', 'Player Name', 'Player Team', 'Home',
#        'Opponent'],
#       dtype='object')

# %%
new_columns_order = ['Season ID', 'Player ID', 'Player Name',
                    'Game ID', 'Game Date', 'Matchup', 'Player Team', 'Opponent', 'Home', 'Won',
                    'Minutes played', 'Field Goals Made', 'Field Goals Attempted',
                    'Field Goals 3 Points Made', 'Field Goal 3 Points Attempt',
                    'Free Throws Made', 'Free Throws Attempt', 'Offensive Rebounds',
                    'Defensive Rebounds', 'Assists', 'Steals', 'Blocks', 'Turnovers',
                    'Personal Fouls', 'Points']

# %%
df = df[new_columns_order]
df.head(2)
# Out:
#   Season ID Player ID   Player Name     Game ID  Game Date      Matchup  \
# 0     22018    203500  Steven Adams  0021801226 2019-04-10    OKC @ MIL
# 1     22018    203500  Steven Adams  0021801218 2019-04-09  OKC vs. HOU
#
#   Player Team Opponent  Home  Won  ...  Free Throws Made  Free Throws Attempt  \
# 0         OKC      MIL     0    1  ...                 2                    4
# 1         OKC      HOU     1    1  ...                 2                    4
#
#    Offensive Rebounds  Defensive Rebounds  Assists  Steals  Blocks  Turnovers  \
# 0                   2                   0        0       0       1          0
# 1                   8                   5        1       0       0          0
#
#    Personal Fouls  Points
# 0               1       4
# 1               1       8
#
# [2 rows x 25 columns]

# %% [markdown]
# ### Include PER (Player Efficiency Ratings)

# %% [markdown]
# PER = (FGM x 85.910 + Steals x 53.897 + 3PTM x 51.757 + FTM x 46.845 + Blocks x 39.190 + Offensive_Reb x 39.190 + Assists x 34.677 + Defensive_Reb x 14.707 — Foul x 17.174 — FT_Miss x 20.091 — FG_Miss x 39.190 — TO x 53.897) x (1 / Minutes)
#
# Reference: https://towardsdatascience.com/predicting-the-outcome-of-nba-games-with-machine-learning-a810bb768f20

# %%
df.columns
# Out:
# Index(['Season ID', 'Player ID', 'Player Name', 'Game ID', 'Game Date',
#        'Matchup', 'Player Team', 'Opponent', 'Home', 'Won', 'Minutes played',
#        'Field Goals Made', 'Field Goals Attempted',
#        'Field Goals 3 Points Made', 'Field Goal 3 Points Attempt',
#        'Free Throws Made', 'Free Throws Attempt', 'Offensive Rebounds',
#        'Defensive Rebounds', 'Assists', 'Steals', 'Blocks', 'Turnovers',
#        'Personal Fouls', 'Points'],
#       dtype='object')

# %%
pers = []
for idx, row in df.iterrows():
    if row['Minutes played'] == 0:
        per = 0
    else:
        per = round((row['Field Goals Made'] * 85.910 + row['Steals'] * 53.897 + row['Field Goals 3 Points Made'] * 51.757 + row['Free Throws Made'] * 46.845 + row['Blocks'] * 39.190 + row['Offensive Rebounds'] * 39.190 + row['Assists'] * 34.677 + row['Defensive Rebounds'] * 14.707 - row['Personal Fouls'] * 17.174 - (row['Free Throws Attempt'] - row['Free Throws Made']) * 20.091 - (row['Free Throws Attempt'] - row['Free Throws Made']) * 39.190 - row['Turnovers'] * 53.897) * (1 / row['Minutes played']), 3)
    pers.append(per)

df['Player Efficiency Ratings'] = pers

# %%
df.head(2)
# Out:
#   Season ID Player ID   Player Name     Game ID  Game Date      Matchup  \
# 0     22018    203500  Steven Adams  0021801226 2019-04-10    OKC @ MIL
# 1     22018    203500  Steven Adams  0021801218 2019-04-09  OKC vs. HOU
#
#   Player Team Opponent  Home  Won  ...  Free Throws Attempt  \
# 0         OKC      MIL     0    1  ...                    4
# 1         OKC      HOU     1    1  ...                    4
#
#    Offensive Rebounds  Defensive Rebounds  Assists  Steals  Blocks  Turnovers  \
# 0                   2                   0        0       0       1          0
# 1                   8                   5        1       0       0          0
#
#    Personal Fouls  Points  Player Efficiency Ratings
# 0               1       4                     13.453
# 1               1       8                     17.227
#
# [2 rows x 26 columns]

# %% [markdown]
# ## Save the DataFrame

# %%
import pickle
import pandas as pd

# Pickle
# with open('Datasets/df_2018_to_2022_raw_with_extra_features.pkl', 'wb') as f:
    # pickle.dump(df, f)

# Unpickle
# with open('Datasets/df_2018_to_2021_raw_with_extra_features.pkl', 'rb') as f:
    # df = pickle.load(f)

# %% [markdown]
# ## Get the next games

# %%
playernextngames.PlayerNextNGames(
    number_of_games=3,
    player_id=players_ids[0], 
    season_all='2021-22', 
    season_type_all_star=season_type).get_data_frames()[0]
# Out:
#       GAME_ID     GAME_DATE  HOME_TEAM_ID  VISITOR_TEAM_ID HOME_TEAM_NAME  \
# 0  0022100790  FEB 04, 2022    1610612761       1610612737        Toronto
# 1  0022100810  FEB 07, 2022    1610612766       1610612761      Charlotte
# 2  0022100827  FEB 09, 2022    1610612760       1610612761  Oklahoma City
#
#   VISITOR_TEAM_NAME HOME_TEAM_ABBREVIATION VISITOR_TEAM_ABBREVIATION  \
# 0           Atlanta                    TOR                       ATL
# 1           Toronto                    CHA                       TOR
# 2           Toronto                    OKC                       TOR
#
#   HOME_TEAM_NICKNAME VISITOR_TEAM_NICKNAME GAME_TIME HOME_WL VISITOR_WL
# 0            Raptors                 Hawks  07:30 PM   27-23      25-26
# 1            Hornets               Raptors  07:00 PM   28-24      27-23
# 2            Thunder               Raptors  08:00 PM   16-34      27-23

# %% [markdown]
# ## Function to retrieve the mean value of players stats

# %%
def get_mean_player_stats(df, player_id, ref_date, n_days, opponent='Any'):
    """
    df: Pandas DataFrame with the data
    ref_date: String with the reference date (YYYY-MM-DD)
    n_days: Number of records to be used in the mean
    opponent: String of the opponenet name, with 3 leters
    """
    columns_to_get_mean = ['Minutes played',
       'Field Goals Made', 'Field Goals Attempted',
       'Field Goals 3 Points Made', 'Field Goal 3 Points Attempt',
       'Free Throws Made', 'Free Throws Attempt', 'Offensive Rebounds',
       'Defensive Rebounds', 'Assists', 'Steals', 'Blocks', 'Turnovers',
       'Points', 'Player Efficiency Ratings']
    opponent = opponent.upper()
    ref_date = pd.to_datetime(ref_date)
    
    if opponent == 'ANY':
        result = df[(df['Player ID'] == player_id) & (df['Game Date'] < ref_date)].sort_values('Game Date', ascending=False).loc[:][0:n_days]
        if result.shape[0] == 0:
            print("The search did not retrieve any result")
            return None
    else:
        result = df[(df['Player ID'] == player_id) & (df['Game Date'] < ref_date) & (df['Opponent'] == opponent)].sort_values('Game Date', ascending=False).loc[:][0:n_days]
        if result.shape[0] == 0:
            print("The search did not retrieve any result")
            return None
    return result[columns_to_get_mean].mean()

# %%
# Function test
player_id = '2544' # LeBron James
date = '2021-12-28'
opponent = 'GSW'
n_days = 4

get_mean_player_stats(df, player_id, date, n_days, opponent)
# Out:
# Minutes played                 30.666667
# Field Goals Made                7.000000
# Field Goals Attempted          13.666667
# Field Goals 3 Points Made       2.333333
# Field Goal 3 Points Attempt     5.333333
# Free Throws Made                3.666667
# Free Throws Attempt             6.000000
# Offensive Rebounds              1.000000
# Defensive Rebounds              6.000000
# Assists                         6.666667
# Steals                          1.000000
# Blocks                          0.666667
# Turnovers                       4.333333
# Points                         20.000000
# Player Efficiency Ratings      32.185667
# dtype: float64

# %% [markdown]
# ## Get Player Position

# %%
test = commonplayerinfo.CommonPlayerInfo(player_id='2544').get_data_frames()[0]
test.head()
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0       2544     LeBron     James       LeBron James            James, LeBron
#
#   DISPLAY_FI_LAST   PLAYER_SLUG            BIRTHDATE  \
# 0        L. James  lebron-james  1984-12-30T00:00:00
#
#                          SCHOOL COUNTRY  ...    PLAYERCODE FROM_YEAR TO_YEAR  \
# 0  St. Vincent-St. Mary HS (OH)     USA  ...  lebron_james      2003    2021
#
#    DLEAGUE_FLAG NBA_FLAG GAMES_PLAYED_FLAG DRAFT_YEAR DRAFT_ROUND  \
# 0             N        Y                 Y       2003           1
#
#    DRAFT_NUMBER GREATEST_75_FLAG
# 0             1                Y
#
# [1 rows x 33 columns]

# %%
test.columns
# Out:
# Index(['PERSON_ID', 'FIRST_NAME', 'LAST_NAME', 'DISPLAY_FIRST_LAST',
#        'DISPLAY_LAST_COMMA_FIRST', 'DISPLAY_FI_LAST', 'PLAYER_SLUG',
#        'BIRTHDATE', 'SCHOOL', 'COUNTRY', 'LAST_AFFILIATION', 'HEIGHT',
#        'WEIGHT', 'SEASON_EXP', 'JERSEY', 'POSITION', 'ROSTERSTATUS',
#        'GAMES_PLAYED_CURRENT_SEASON_FLAG', 'TEAM_ID', 'TEAM_NAME',
#        'TEAM_ABBREVIATION', 'TEAM_CODE', 'TEAM_CITY', 'PLAYERCODE',
#        'FROM_YEAR', 'TO_YEAR', 'DLEAGUE_FLAG', 'NBA_FLAG', 'GAMES_PLAYED_FLAG',
#        'DRAFT_YEAR', 'DRAFT_ROUND', 'DRAFT_NUMBER', 'GREATEST_75_FLAG'],
#       dtype='object')

# %%
test['POSITION'].values[0]
# Out:
# 'Forward'

# %%
df.columns
# Out:
# Index(['Season ID', 'Player ID', 'Player Name', 'Game ID', 'Game Date',
#        'Matchup', 'Player Team', 'Opponent', 'Home', 'Won', 'Minutes played',
#        'Field Goals Made', 'Field Goals Attempted',
#        'Field Goals 3 Points Made', 'Field Goal 3 Points Attempt',
#        'Free Throws Made', 'Free Throws Attempt', 'Offensive Rebounds',
#        'Defensive Rebounds', 'Assists', 'Steals', 'Blocks', 'Turnovers',
#        'Personal Fouls', 'Points', 'Player Efficiency Ratings'],
#       dtype='object')

# %%
def get_player_position(id_list) -> dict:
    player_id_position = {}
    for idx, id in enumerate(id_list):
        info = commonplayerinfo.CommonPlayerInfo(player_id=id).get_data_frames()[0]
        player_id_position[id] = info['POSITION'].values[0]
        # Preventing timeout exceptions
        time.sleep(.600)
    return player_id_position

# %%
player_positions = get_player_position(players_ids)

# %%
# Player ID: '2544'
# Player Name: LeBron James
# Expected Value: Forward

player_positions['2544']
# Out:
# 'Forward'

# %%
# Count players with missing possition
missing = []
for key, value in player_positions.items():
    if value == '':
        missing.append(key)

len(missing)
# Out:
# 17

# %%
for player in active_players:
    if str(player['id']) in missing:
        print(player['full_name'])
# Out:
# Derrick Alston Jr.
# Mitch Ballock
# D.J. Carton
# Matt Coleman III
# Johnny Hamilton
# Daulton Hommes
# Feron Hunt
# AJ Lawson
# Matt Lewis
# Isaiah Miller
# Matt Ryan
# Aamir Simms
# Dru Smith
# DJ Steward
# DJ Stewart
# MaCio Teague
# Ethan Thompson

# %% [markdown]
# Only irrelevant players. Possible solutions:
# - Remove them from the dataset
# - Define a "default" position for them
# - Insert manually
#
# To be decided.

# %%
import pickle

# Pickle
# with open('player_positions.pkl', 'wb') as f:
#     pickle.dump(player_positions, f)

# Unpickle
# with open('player_positions.pkl', 'rb') as f:
    # player_positions = pickle.load(f)

# %% [markdown]
# ## Get players' salary and position from DraftKings
#
# Reference: https://swishanalytics.com/optimus/nba/daily-fantasy-salary-changes

# %%
# %pip install requests beautifulsoup4
# %pip install lxml

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://swishanalytics.com/optimus/nba/daily-fantasy-salary-changes"

html_content = requests.get(url).text

# Parse the html content
soup = BeautifulSoup(html_content, "lxml")
print(soup.prettify()[:200]) # print the parsed data of html
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <style>
#   </style>
#   <script type="text/javascript">
#    (function(e,b){if(!b.__SV){var a,f,i,g;window.mixpanel=b;b._i=[];b.init=function(a,e,d)

# %%
scripts = soup.findAll('script')

# %%
scripts[21]
# Out:
# <script>
#       function Model(){
#         this.players_dk = [{"player_id":"1121277","player_name":"Luka Doncic","nickname":"Mavericks","pos_main":"PG","fantasy_pts":"62.69","avg_pts":"56.41","fpts_diff":"+6.28","date":"2022-02-28","salary":"21,900","salary_diff":"21899","salary_diff_percentage":"2189900.0","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$21899 (2189900.0%)<\/td>","salary_change":"2189900.0"},{"player_id":"214152","player_name":"LeBron James","nickname":"Lakers","pos_main":"SF","fantasy_pts":"51.93","avg_pts":"54.07","fpts_diff":"-2.14","date":"2022-02-28","salary":"20,700","salary_diff":"20695","salary_diff_percentage":"413900.0","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$20695 (413900.0%)<\/td>","salary_change":"413900.0"},{"player_id":"338365","player_name":"Stephen Curry","nickname":"Warriors","pos_main":"PG","fantasy_pts":"48.84","avg_pts":"46.64","fpts_diff":"+2.20","date":"2022-02-28","salary":"10,800","salary_diff":"10793","salary_diff_percentage":"154185.7","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$10793 (154185.7%)<\/td>","salary_change":"154185.7"},{"player_id":"329830","player_name":"Russell Westbrook","nickname":"Lakers","pos_main":"PG","fantasy_pts":"35.00","avg_pts":"40.94","fpts_diff":"-5.94","date":"2022-02-28","salary":"15,600","salary_diff":"15588","salary_diff_percentage":"129900.0","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$15588 (129900.0%)<\/td>","salary_change":"129900.0"},{"player_id":"837030","player_name":"Karl-Anthony Towns","nickname":"Timberwolves","pos_main":"C","fantasy_pts":"46.32","avg_pts":"46.73","fpts_diff":"-0.41","date":"2022-02-28","salary":"10,100","salary_diff":"10089","salary_diff_percentage":"91718.2","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$10089 (91718.2%)<\/td>","salary_change":"91718.2"},{"player_id":"853408","player_name":"Pascal Siakam","nickname":"Raptors","pos_main":"PF","fantasy_pts":"43.34","avg_pts":"43.35","fpts_diff":"-0.01","date":"2022-02-28","salary":"8,900","salary_diff":"8862","salary_diff_percentage":"23321.1","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$8862 (23321.1%)<\/td>","salary_change":"23321.1"},{"player_id":"707832","player_name":"Fred VanVleet","nickname":"Raptors","pos_main":"PG","fantasy_pts":"20.28","avg_pts":"42.65","fpts_diff":"-22.37","date":"2022-02-28","salary":"8,500","salary_diff":"8461","salary_diff_percentage":"21694.9","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$8461 (21694.9%)<\/td>","salary_change":"21694.9"},{"player_id":"614746","player_name":"Andre Drummond","nickname":"Nets","pos_main":"C","fantasy_pts":"29.61","avg_pts":"24.35","fpts_diff":"+5.26","date":"2022-02-28","salary":"6,900","salary_diff":"6867","salary_diff_percentage":"20809.1","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$6867 (20809.1%)<\/td>","salary_change":"20809.1"},{"player_id":"602411","player_name":"Spencer Dinwiddie","nickname":"Mavericks","pos_main":"PG","fantasy_pts":"23.87","avg_pts":"28.79","fpts_diff":"-4.92","date":"2022-02-28","salary":"11,100","salary_diff":"11038","salary_diff_percentage":"17803.2","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$11038 (17803.2%)<\/td>","salary_change":"17803.2"},{"player_id":"844038","player_name":"D'Angelo Russell","nickname":"Timberwolves","pos_main":"PG","fantasy_pts":"35.32","avg_pts":"37.24","fpts_diff":"-1.92","date":"2022-02-28","salary":"7,600","salary_diff":"7553","salary_diff_percentage":"16070.2","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$7553 (16070.2%)<\/td>","salary_change":"16070.2"},{"player_id":"750924","player_name":"Christian Wood","nickname":"Rockets","pos_main":"C","fantasy_pts":"36.26","avg_pts":"37.47","fpts_diff":"-1.21","date":"2022-02-28","salary":"8,100","salary_diff":"8047","salary_diff_percentage":"15183.0","salary_change_html":"<td class=\"width-15 g ...
#         console.log(this.players_dk);
#         this.players_fd = [{"player_id":"332691","player_name":"Patrick Beverley","nickname":"Timberwolves","pos_main":"PG","fantasy_pts":"24.53","avg_pts":"26.53","fpts_diff":"-2.00","date":"2022-02-28","salary":"4,700","salary_diff":"4698","salary_diff_percentage":"234900.0","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$4698 (234900.0%)<\/td>","salary_change":"234900.0"},{"player_id":"1175367","player_name":"Anthony Edwards","nickname":"Timberwolves","pos_main":"SF","fantasy_pts":"34.03","avg_pts":"36.30","fpts_diff":"-2.27","date":"2022-02-28","salary":"6,600","salary_diff":"6597","salary_diff_percentage":"219900.0","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$6597 (219900.0%)<\/td>","salary_change":"219900.0"},{"player_id":"1137200","player_name":"Naz Reid","nickname":"Timberwolves","pos_main":"C","fantasy_pts":"12.71","avg_pts":"17.31","fpts_diff":"-4.60","date":"2022-02-28","salary":"4,100","salary_diff":"4098","salary_diff_percentage":"204900.0","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$4098 (204900.0%)<\/td>","salary_change":"204900.0"},{"player_id":"879503","player_name":"Malik Beasley","nickname":"Timberwolves","pos_main":"SF","fantasy_pts":"13.87","avg_pts":"18.82","fpts_diff":"-4.95","date":"2022-02-28","salary":"3,600","salary_diff":"3598","salary_diff_percentage":"179900.0","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$3598 (179900.0%)<\/td>","salary_change":"179900.0"},{"player_id":"696209","player_name":"Taurean Waller-Prince","nickname":"Timberwolves","pos_main":"SF","fantasy_pts":"15.01","avg_pts":"11.98","fpts_diff":"+3.03","date":"2022-02-28","salary":"3,500","salary_diff":"3498","salary_diff_percentage":"174900.0","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$3498 (174900.0%)<\/td>","salary_change":"174900.0"},{"player_id":"844465","player_name":"Jordan McLaughlin","nickname":"Timberwolves","pos_main":"PG","fantasy_pts":"10.09","avg_pts":"10.58","fpts_diff":"-0.49","date":"2022-02-28","salary":"3,500","salary_diff":"3498","salary_diff_percentage":"174900.0","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$3498 (174900.0%)<\/td>","salary_change":"174900.0"},{"player_id":"602411","player_name":"Spencer Dinwiddie","nickname":"Mavericks","pos_main":"PG","fantasy_pts":"23.11","avg_pts":"27.51","fpts_diff":"-4.40","date":"2022-02-27","salary":"12,500","salary_diff":"8000","salary_diff_percentage":"177.8","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$8000 (177.8%)<\/td>","salary_change":"177.8"},{"player_id":"552309","player_name":"Dwight Powell","nickname":"Mavericks","pos_main":"C","fantasy_pts":"18.85","avg_pts":"16.46","fpts_diff":"+2.39","date":"2022-02-27","salary":"9,000","salary_diff":"5300","salary_diff_percentage":"143.2","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$5300 (143.2%)<\/td>","salary_change":"143.2"},{"player_id":"953291","player_name":"Austin Reaves","nickname":"Lakers","pos_main":"SG","fantasy_pts":"13.76","avg_pts":"12.20","fpts_diff":"+1.56","date":"2022-02-27","salary":"8,500","salary_diff":"4900","salary_diff_percentage":"136.1","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$4900 (136.1%)<\/td>","salary_change":"136.1"},{"player_id":"599814","player_name":"Dave Bertans","nickname":"Mavericks","pos_main":"SF","fantasy_pts":"12.03","avg_pts":"10.29","fpts_diff":"+1.74","date":"2022-02-27","salary":"8,000","salary_diff":"4500","salary_diff_percentage":"128.6","salary_change_html":"<td class=\"width-15 green\" id=\"salary-col\">+$4500 (128.6%)<\/td>","salary_change":"128.6"},{"player_id":"1072048","player_name":"Maxi Kleber","nickname":"Mavericks","pos_main":"PF","fantasy_pts":"19.93","avg_pts":"20.65","fpts_diff":"-0.72","date":"2022-02-27","salary":"11,500","salary_diff":"6400","salary_diff_percentage":"125.5","salary_change_html":"<td class=\"width-15 green\" id=\" ...
#         this.players_ya = [];
#         this.current_site = 'dk';
#       }
#       Model.prototype = {
#         determineSortFunction: function(type){
#           var self = this;
#           if(type=='player_name'||type=='pos_main'){
#             self.currentSort = type;
#             self.sortFunction = self.alph_sort;
#             return self.sortFunction;
#           }else if(type=='salary'||type=='salary_diff'){
#             self.currentSort = type;
#             self.sortFunction = self.salary_sort;
#             return self.sortFunction;
#           }else{
#             self.currentSort = type;
#             self.sortFunction = self.float_sort;
#             return self.sortFunction;
#           }
#         },
#         alph_sort: function(key,a,b){
#           if((a[key]) < (b[key])) return -1;
#           if((a[key]) > (b[key])) return 1;
#           return 0;
#         },
#         time_sort: function(key,a,b){
#           if((a['date']) < (b['date'])) return -1;
#           if((a['date']) > (b['date'])) return 1;
#           return 0;
#         },
#         salary_sort: function(key,a,b){
#           if(parseInt(a[key]) < parseInt(b[key])) return -1;
#           if(parseInt(a[key]) > parseInt(b[key])) return 1;
#           return 0;
#         },
#         float_sort: function(key,a,b){
#           if(parseFloat(a[key]) < parseFloat(b[key])) return -1;
#           if(parseFloat(a[key]) > parseFloat(b[key])) return 1;
#           return 0;
#         },
#         default_sort: function(a,b){
#           if(parseFloat(a[this.currentSite+'_fpts']) < parseFloat(b[this.currentSite+'_fpts'])) return -1;
#           if(parseFloat(a[this.currentSite+'_fpts']) > parseFloat(b[this.currentSite+'_fpts'])) return 1;
#           return 0;
#         }
#       }
#
#       function View(){
#
#       }
#       View.prototype = {
#         fillPlayerPool: function(players){
#           var self = this;
#           $('.stat-table').empty();
#           $.each(players,function(key,value){
#             var player_string = '<tr class="salary-row">'+
#                                 '<td id="salary-col" class="width-10 text-left">'+value.pos_main+'</td>'+
#                                 '<td id="salary-col" class="width-20 text-left "><img src="/style/assets/img/nba/teams/'+value.nickname.replace(" ","_").toLowerCase()+'.png" height="20px" class="pad-right-5"> '+value.player_name+'</td>'+
#                                 '<td class="width-15" id="salary-col">$'+value.salary+'</td>'+
#                                 '<td class="width-15 '+self.determineColor(parseInt(value.salary_diff))+'" id="salary-col">'+self.formatSalary(parseInt(value.salary_diff))+' ('+value.salary_diff_percentage+'%)</td>'+
#                                 '<td class="width-15" id="salary-col">'+value.fantasy_pts+'</td>'+
#                                 '<td class="width-15" id="salary-col">'+value.avg_pts+'</td>'+
#                                 '<td class="width-10" id="salary-col">'+value.fpts_diff+'</td></tr>';
#             $('.stat-table').append(player_string);
#           })
#         },
#         determineColor: function(salary){
#           if(salary<0){
#             return 'red';
#           }else{
#             return 'green';
#           }
#         },
#         formatSalary: function(salary){
#           if(salary>0){
#             return '+$'+salary;
#           }else{
#             return '-$'+(salary*-1);
#           }
#         }
#       }
#
#       function Controller(){
#         this.model = new Model();
#         this.view = new View();
#       }
#       Controller.prototype = {
#         fillPlayerPool: function(){
#           this.view.fillPlayerPool(this.model['players_'+this.model.current_site])
#         },
#         siteListener: function(){
#           var self = this;
#           $('.fantasySite').click(function(e){
#             e.preventDefault();
#             self.model.current_site = $(this).attr('site');
#             $('.fantasy-parent').children().removeClass('active activeSite');
#             $(this).addClass('active activeSite');
#             self.fillPlayerPool();
#           });
#         },
#         sortListener: function(){
#           var self = this;
#           $(document).on('click','.stat-sort',function(){
#             var sortFunction = self.model.determineSortFunction($(this).attr('type'));
#             if ($(this).hasClass('sorted')){
#               $(this).removeClass('sorted');
#               $(this).addClass('reverseSorted');
#               var sortBy = 'reverse';
#             } else if ($(this).hasClass('reverseSorted')){
#               $(this).removeClass('reverseSorted');
#               $('.sortTriggers').children().removeClass('sorted');
#               var sortBy = 'unsort';
#             } else {
#               $('.sortTriggers').children().removeClass('sorted');
#               $('.sortTriggers').children().removeClass('reverseSorted');
#               $(this).addClass('sorted');
#               var sortBy = 'sort';
#             }
#             self.performSort(sortFunction, sortBy);
#           })
#         },
#         performSort: function(sortFunction, sortBy){
#           var self = this;
#           if (sortBy == 'sort'){
#             self.model['players_'+self.model.current_site].sort(sortFunction.bind(null, self.model.currentSort));
#           } else if (sortBy == 'reverse'){
#             self.model['players_'+self.model.current_site].sort(sortFunction.bind(null, self.model.currentSort)).reverse();
#           } else if (sortBy == 'unsort'){
#             self.model['players_'+self.model.current_site].sort(self.model.float_sort.bind(null, self.model.currentSite+'_fpts')).reverse();
#           }
#           self.fillPlayerPool();
#         }
#       }
#
#       $(document).ready(function(){
#         var controller = new Controller();
#         controller.fillPlayerPool();
#         controller.siteListener();
#         controller.sortListener();
#       })
#
#
#
#     </script>

# %%
table = scripts[21].contents[0]

# %%
table = table.split('{')
table
# Out:
# ['\n      function Model()',
#  '\n        this.players_dk = [',
#  '"player_id":"1121277","player_name":"Luka Doncic","nickname":"Mavericks","pos_main":"PG","fantasy_pts":"62.69","avg_pts":"56.41","fpts_diff":"+6.28","date":"2022-02-28","salary":"21,900","salary_diff":"21899","salary_diff_percentage":"2189900.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$21899 (2189900.0%)<\\/td>","salary_change":"2189900.0"},',
#  '"player_id":"214152","player_name":"LeBron James","nickname":"Lakers","pos_main":"SF","fantasy_pts":"51.93","avg_pts":"54.07","fpts_diff":"-2.14","date":"2022-02-28","salary":"20,700","salary_diff":"20695","salary_diff_percentage":"413900.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$20695 (413900.0%)<\\/td>","salary_change":"413900.0"},',
#  '"player_id":"338365","player_name":"Stephen Curry","nickname":"Warriors","pos_main":"PG","fantasy_pts":"48.84","avg_pts":"46.64","fpts_diff":"+2.20","date":"2022-02-28","salary":"10,800","salary_diff":"10793","salary_diff_percentage":"154185.7","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$10793 (154185.7%)<\\/td>","salary_change":"154185.7"},',
#  '"player_id":"329830","player_name":"Russell Westbrook","nickname":"Lakers","pos_main":"PG","fantasy_pts":"35.00","avg_pts":"40.94","fpts_diff":"-5.94","date":"2022-02-28","salary":"15,600","salary_diff":"15588","salary_diff_percentage":"129900.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$15588 (129900.0%)<\\/td>","salary_change":"129900.0"},',
#  '"player_id":"837030","player_name":"Karl-Anthony Towns","nickname":"Timberwolves","pos_main":"C","fantasy_pts":"46.32","avg_pts":"46.73","fpts_diff":"-0.41","date":"2022-02-28","salary":"10,100","salary_diff":"10089","salary_diff_percentage":"91718.2","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$10089 (91718.2%)<\\/td>","salary_change":"91718.2"},',
#  '"player_id":"853408","player_name":"Pascal Siakam","nickname":"Raptors","pos_main":"PF","fantasy_pts":"43.34","avg_pts":"43.35","fpts_diff":"-0.01","date":"2022-02-28","salary":"8,900","salary_diff":"8862","salary_diff_percentage":"23321.1","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$8862 (23321.1%)<\\/td>","salary_change":"23321.1"},',
#  '"player_id":"707832","player_name":"Fred VanVleet","nickname":"Raptors","pos_main":"PG","fantasy_pts":"20.28","avg_pts":"42.65","fpts_diff":"-22.37","date":"2022-02-28","salary":"8,500","salary_diff":"8461","salary_diff_percentage":"21694.9","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$8461 (21694.9%)<\\/td>","salary_change":"21694.9"},',
#  '"player_id":"614746","player_name":"Andre Drummond","nickname":"Nets","pos_main":"C","fantasy_pts":"29.61","avg_pts":"24.35","fpts_diff":"+5.26","date":"2022-02-28","salary":"6,900","salary_diff":"6867","salary_diff_percentage":"20809.1","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$6867 (20809.1%)<\\/td>","salary_change":"20809.1"},',
#  '"player_id":"602411","player_name":"Spencer Dinwiddie","nickname":"Mavericks","pos_main":"PG","fantasy_pts":"23.87","avg_pts":"28.79","fpts_diff":"-4.92","date":"2022-02-28","salary":"11,100","salary_diff":"11038","salary_diff_percentage":"17803.2","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$11038 (17803.2%)<\\/td>","salary_change":"17803.2"},',
#  '"player_id":"844038","player_name":"D\'Angelo Russell","nickname":"Timberwolves","pos_main":"PG","fantasy_pts":"35.32","avg_pts":"37.24","fpts_diff":"-1.92","date":"2022-02-28","salary":"7,600","salary_diff":"7553","salary_diff_percentage":"16070.2","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$7553 (16070.2%)<\\/td>","salary_change":"16070.2"},',
#  '"player_id":"750924","player_name":"Christian Wood","nickname":"Rockets","pos_main":"C","fantasy_pts":"36.26","avg_pts":"37.47","fpts_diff":"-1.21","date":"2022-02-28","salary":"8,100","salary_diff":"8047","salary_diff_percentage":"15183.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$8047 (15183.0%)<\\/td>","salary_change":"15183.0"},',
#  '"player_id":"1232182","player_name":"Cade Cunningham","nickname":"Pistons","pos_main":"SG","fantasy_pts":"33.95","avg_pts":"33.91","fpts_diff":"+0.04","date":"2022-02-28","salary":"14,400","salary_diff":"14300","salary_diff_percentage":"14300.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$14300 (14300.0%)<\\/td>","salary_change":"14300.0"},',
#  '"player_id":"699826","player_name":"Jerami Grant","nickname":"Pistons","pos_main":"PF","fantasy_pts":"28.99","avg_pts":"31.67","fpts_diff":"-2.68","date":"2022-02-28","salary":"12,300","salary_diff":"12209","salary_diff_percentage":"13416.5","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$12209 (13416.5%)<\\/td>","salary_change":"13416.5"},',
#  '"player_id":"1175367","player_name":"Anthony Edwards","nickname":"Timberwolves","pos_main":"SG","fantasy_pts":"34.73","avg_pts":"37.27","fpts_diff":"-2.54","date":"2022-02-28","salary":"7,400","salary_diff":"7331","salary_diff_percentage":"10624.6","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$7331 (10624.6%)<\\/td>","salary_change":"10624.6"},',
#  '"player_id":"794503","player_name":"Andrew Wiggins","nickname":"Warriors","pos_main":"SF","fantasy_pts":"30.20","avg_pts":"29.88","fpts_diff":"+0.32","date":"2022-02-28","salary":"6,200","salary_diff":"6134","salary_diff_percentage":"9293.9","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$6134 (9293.9%)<\\/td>","salary_change":"9293.9"},',
#  '"player_id":"739958","player_name":"Dennis Schroder","nickname":"Rockets","pos_main":"PG","fantasy_pts":"26.71","avg_pts":"26.74","fpts_diff":"-0.03","date":"2022-02-28","salary":"5,900","salary_diff":"5822","salary_diff_percentage":"7464.1","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$5822 (7464.1%)<\\/td>","salary_change":"7464.1"},',
#  '"player_id":"1138653","player_name":"Saddiq Bey","nickname":"Pistons","pos_main":"SF","fantasy_pts":"30.27","avg_pts":"30.29","fpts_diff":"-0.02","date":"2022-02-28","salary":"12,900","salary_diff":"12718","salary_diff_percentage":"6987.9","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$12718 (6987.9%)<\\/td>","salary_change":"6987.9"},',
#  '"player_id":"514882","player_name":"Kelly Olynyk","nickname":"Pistons","pos_main":"PF","fantasy_pts":"22.40","avg_pts":"22.51","fpts_diff":"-0.11","date":"2022-02-28","salary":"9,600","salary_diff":"9461","salary_diff_percentage":"6806.5","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$9461 (6806.5%)<\\/td>","salary_change":"6806.5"},',
#  '"player_id":"887914","player_name":"Jalen Brunson","nickname":"Mavericks","pos_main":"PG","fantasy_pts":"30.52","avg_pts":"30.36","fpts_diff":"+0.16","date":"2022-02-28","salary":"12,600","salary_diff":"12399","salary_diff_percentage":"6168.7","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$12399 (6168.7%)<\\/td>","salary_change":"6168.7"},',
#  '"player_id":"1135158","player_name":"Kevin Porter Jr.","nickname":"Rockets","pos_main":"PG","fantasy_pts":"14.50","avg_pts":"29.99","fpts_diff":"-15.49","date":"2022-02-28","salary":"6,000","salary_diff":"5903","salary_diff_percentage":"6085.6","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$5903 (6085.6%)<\\/td>","salary_change":"6085.6"},',
#  '"player_id":"266554","player_name":"LaMarcus Aldridge","nickname":"Nets","pos_main":"C","fantasy_pts":"21.77","avg_pts":"24.38","fpts_diff":"-2.61","date":"2022-02-28","salary":"4,500","salary_diff":"4425","salary_diff_percentage":"5900.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$4425 (5900.0%)<\\/td>","salary_change":"5900.0"},',
#  '"player_id":"172890","player_name":"Carmelo Anthony","nickname":"Lakers","pos_main":"PF","fantasy_pts":"22.92","avg_pts":"24.19","fpts_diff":"-1.27","date":"2022-02-28","salary":"8,700","salary_diff":"8553","salary_diff_percentage":"5818.4","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$8553 (5818.4%)<\\/td>","salary_change":"5818.4"},',
#  '"player_id":"606701","player_name":"Dorian Finney-Smith","nickname":"Mavericks","pos_main":"SF","fantasy_pts":"23.35","avg_pts":"22.84","fpts_diff":"+0.51","date":"2022-02-28","salary":"9,300","salary_diff":"9137","salary_diff_percentage":"5605.5","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$9137 (5605.5%)<\\/td>","salary_change":"5605.5"},',
#  '"player_id":"1271706","player_name":"Jalen Green","nickname":"Rockets","pos_main":"PG","fantasy_pts":"25.87","avg_pts":"23.83","fpts_diff":"+2.04","date":"2022-02-28","salary":"5,500","salary_diff":"5393","salary_diff_percentage":"5040.2","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$5393 (5040.2%)<\\/td>","salary_change":"5040.2"},',
#  '"player_id":"1076209","player_name":"Marvin Bagley III","nickname":"Pistons","pos_main":"PF","fantasy_pts":"11.27","avg_pts":"20.48","fpts_diff":"-9.21","date":"2022-02-28","salary":"5,700","salary_diff":"5580","salary_diff_percentage":"4650.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$5580 (4650.0%)<\\/td>","salary_change":"4650.0"},',
#  '"player_id":"1177050","player_name":"Isaiah Stewart","nickname":"Pistons","pos_main":"C","fantasy_pts":"25.25","avg_pts":"23.24","fpts_diff":"+2.01","date":"2022-02-28","salary":"9,900","salary_diff":"9688","salary_diff_percentage":"4569.8","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$9688 (4569.8%)<\\/td>","salary_change":"4569.8"},',
#  '"player_id":"844040","player_name":"Jae\'Sean Tate","nickname":"Rockets","pos_main":"PF","fantasy_pts":"28.21","avg_pts":"27.18","fpts_diff":"+1.03","date":"2022-02-28","salary":"6,100","salary_diff":"5957","salary_diff_percentage":"4165.7","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$5957 (4165.7%)<\\/td>","salary_change":"4165.7"},',
#  '"player_id":"456456","player_name":"Goran Dragic","nickname":"Nets","pos_main":"PG","fantasy_pts":"14.04","avg_pts":"15.89","fpts_diff":"-1.85","date":"2022-02-28","salary":"4,100","salary_diff":"4001","salary_diff_percentage":"4041.4","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$4001 (4041.4%)<\\/td>","salary_change":"4041.4"},',
#  '"player_id":"941834","player_name":"Bruce Brown","nickname":"Nets","pos_main":"SF","fantasy_pts":"24.49","avg_pts":"17.45","fpts_diff":"+7.04","date":"2022-02-28","salary":"5,400","salary_diff":"5267","salary_diff_percentage":"3960.2","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$5267 (3960.2%)<\\/td>","salary_change":"3960.2"},',
#  '"player_id":"957492","player_name":"Malik Monk","nickname":"Lakers","pos_main":"PG","fantasy_pts":"20.01","avg_pts":"23.06","fpts_diff":"-3.05","date":"2022-02-28","salary":"8,400","salary_diff":"8173","salary_diff_percentage":"3600.4","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$8173 (3600.4%)<\\/td>","salary_change":"3600.4"},',
#  '"player_id":"463135","player_name":"Seth Curry","nickname":"Nets","pos_main":"SG","fantasy_pts":"26.37","avg_pts":"27.86","fpts_diff":"-1.49","date":"2022-02-28","salary":"6,400","salary_diff":"6226","salary_diff_percentage":"3578.2","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$6226 (3578.2%)<\\/td>","salary_change":"3578.2"},',
#  '"player_id":"401085","player_name":"Eric Gordon","nickname":"Rockets","pos_main":"SG","fantasy_pts":"21.07","avg_pts":"22.90","fpts_diff":"-1.83","date":"2022-02-28","salary":"4,600","salary_diff":"4471","salary_diff_percentage":"3465.9","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$4471 (3465.9%)<\\/td>","salary_change":"3465.9"},',
#  '"player_id":"329683","player_name":"Thaddeus Young","nickname":"Raptors","pos_main":"PF","fantasy_pts":"15.23","avg_pts":"16.02","fpts_diff":"-0.79","date":"2022-02-28","salary":"3,700","salary_diff":"3596","salary_diff_percentage":"3457.7","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3596 (3457.7%)<\\/td>","salary_change":"3457.7"},',
#  '"player_id":"552335","player_name":"Reggie Bullock","nickname":"Mavericks","pos_main":"SG","fantasy_pts":"22.02","avg_pts":"16.12","fpts_diff":"+5.90","date":"2022-02-28","salary":"8,100","salary_diff":"7862","salary_diff_percentage":"3303.4","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$7862 (3303.4%)<\\/td>","salary_change":"3303.4"},',
#  '"player_id":"253975","player_name":"Dwight Howard","nickname":"Lakers","pos_main":"C","fantasy_pts":"21.74","avg_pts":"15.90","fpts_diff":"+5.84","date":"2022-02-28","salary":"7,500","salary_diff":"7279","salary_diff_percentage":"3293.7","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$7279 (3293.7%)<\\/td>","salary_change":"3293.7"},',
#  '"player_id":"1072048","player_name":"Maxi Kleber","nickname":"Mavericks","pos_main":"PF","fantasy_pts":"19.71","avg_pts":"20.58","fpts_diff":"-0.87","date":"2022-02-28","salary":"7,200","salary_diff":"6981","salary_diff_percentage":"3187.7","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$6981 (3187.7%)<\\/td>","salary_change":"3187.7"},',
#  '"player_id":"1060908","player_name":"Gary Trent Jr.","nickname":"Raptors","pos_main":"SG","fantasy_pts":"30.55","avg_pts":"29.77","fpts_diff":"+0.78","date":"2022-02-28","salary":"6,400","salary_diff":"6204","salary_diff_percentage":"3165.3","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$6204 (3165.3%)<\\/td>","salary_change":"3165.3"},',
#  '"player_id":"1132824","player_name":"Talen Horton-Tucker","nickname":"Lakers","pos_main":"SG","fantasy_pts":"18.66","avg_pts":"20.39","fpts_diff":"-1.73","date":"2022-02-28","salary":"7,800","salary_diff":"7561","salary_diff_percentage":"3163.6","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$7561 (3163.6%)<\\/td>","salary_change":"3163.6"},',
#  '"player_id":"879503","player_name":"Malik Beasley","nickname":"Timberwolves","pos_main":"SG","fantasy_pts":"14.74","avg_pts":"20.11","fpts_diff":"-5.37","date":"2022-02-28","salary":"3,300","salary_diff":"3194","salary_diff_percentage":"3013.2","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3194 (3013.2%)<\\/td>","salary_change":"3013.2"},',
#  '"player_id":"901190","player_name":"Chris Boucher","nickname":"Raptors","pos_main":"PF","fantasy_pts":"17.45","avg_pts":"20.09","fpts_diff":"-2.64","date":"2022-02-28","salary":"4,300","salary_diff":"4147","salary_diff_percentage":"2710.5","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$4147 (2710.5%)<\\/td>","salary_change":"2710.5"},',
#  '"player_id":"1257421","player_name":"Killian Hayes","nickname":"Pistons","pos_main":"PG","fantasy_pts":"15.50","avg_pts":"18.58","fpts_diff":"-3.08","date":"2022-02-28","salary":"6,000","salary_diff":"5778","salary_diff_percentage":"2602.7","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$5778 (2602.7%)<\\/td>","salary_change":"2602.7"},',
#  '"player_id":"599814","player_name":"Davis Bertans","nickname":"Mavericks","pos_main":"PF","fantasy_pts":"12.59","avg_pts":"10.80","fpts_diff":"+1.79","date":"2022-02-28","salary":"5,100","salary_diff":"4902","salary_diff_percentage":"2475.8","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$4902 (2475.8%)<\\/td>","salary_change":"2475.8"},',
#  '"player_id":"552805","player_name":"Cory Joseph","nickname":"Pistons","pos_main":"PG","fantasy_pts":"18.12","avg_pts":"18.72","fpts_diff":"-0.60","date":"2022-02-28","salary":"6,600","salary_diff":"6342","salary_diff_percentage":"2458.1","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$6342 (2458.1%)<\\/td>","salary_change":"2458.1"},',
#  '"player_id":"399725","player_name":"Blake Griffin","nickname":"Nets","pos_main":"PF","fantasy_pts":"7.46","avg_pts":"16.37","fpts_diff":"-8.91","date":"2022-02-28","salary":"3,900","salary_diff":"3746","salary_diff_percentage":"2432.5","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3746 (2432.5%)<\\/td>","salary_change":"2432.5"},',
#  '"player_id":"1067671","player_name":"Jordan Poole","nickname":"Warriors","pos_main":"PG","fantasy_pts":"26.46","avg_pts":"27.40","fpts_diff":"-0.94","date":"2022-02-28","salary":"5,200","salary_diff":"4965","salary_diff_percentage":"2112.8","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$4965 (2112.8%)<\\/td>","salary_change":"2112.8"},',
#  '"player_id":"609256","player_name":"Otto Porter Jr.","nickname":"Warriors","pos_main":"SF","fantasy_pts":"21.53","avg_pts":"20.90","fpts_diff":"+0.63","date":"2022-02-28","salary":"4,100","salary_diff":"3914","salary_diff_percentage":"2104.3","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3914 (2104.3%)<\\/td>","salary_change":"2104.3"},',
#  '"player_id":"552309","player_name":"Dwight Powell","nickname":"Mavericks","pos_main":"C","fantasy_pts":"18.47","avg_pts":"16.25","fpts_diff":"+2.22","date":"2022-02-28","salary":"6,600","salary_diff":"6293","salary_diff_percentage":"2049.8","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$6293 (2049.8%)<\\/td>","salary_change":"2049.8"},',
#  '"player_id":"332691","player_name":"Patrick Beverley","nickname":"Timberwolves","pos_main":"PG","fantasy_pts":"24.57","avg_pts":"26.09","fpts_diff":"-1.52","date":"2022-02-28","salary":"5,000","salary_diff":"4749","salary_diff_percentage":"1892.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$4749 (1892.0%)<\\/td>","salary_change":"1892.0"},',
#  '"player_id":"411562","player_name":"Patty Mills","nickname":"Nets","pos_main":"SG","fantasy_pts":"20.34","avg_pts":"22.35","fpts_diff":"-2.01","date":"2022-02-28","salary":"4,600","salary_diff":"4358","salary_diff_percentage":"1800.8","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$4358 (1800.8%)<\\/td>","salary_change":"1800.8"},',
#  '"player_id":"398037","player_name":"James Johnson","nickname":"Nets","pos_main":"PF","fantasy_pts":"21.47","avg_pts":"15.26","fpts_diff":"+6.21","date":"2022-02-28","salary":"4,300","salary_diff":"4071","salary_diff_percentage":"1777.7","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$4071 (1777.7%)<\\/td>","salary_change":"1777.7"},',
#  '"player_id":"229738","player_name":"Trevor Ariza","nickname":"Lakers","pos_main":"PF","fantasy_pts":"10.30","avg_pts":"11.10","fpts_diff":"-0.80","date":"2022-02-28","salary":"3,300","salary_diff":"3120","salary_diff_percentage":"1733.3","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3120 (1733.3%)<\\/td>","salary_change":"1733.3"},',
#  '"player_id":"696209","player_name":"Taurean Prince","nickname":"Timberwolves","pos_main":"SF","fantasy_pts":"15.15","avg_pts":"12.13","fpts_diff":"+3.03","date":"2022-02-28","salary":"3,600","salary_diff":"3403","salary_diff_percentage":"1727.4","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3403 (1727.4%)<\\/td>","salary_change":"1727.4"},',
#  '"player_id":"550431","player_name":"Nemanja Bjelica","nickname":"Warriors","pos_main":"PF","fantasy_pts":"7.56","avg_pts":"15.56","fpts_diff":"-8.00","date":"2022-02-28","salary":"3,500","salary_diff":"3306","salary_diff_percentage":"1704.1","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3306 (1704.1%)<\\/td>","salary_change":"1704.1"},',
#  '"player_id":"1137200","player_name":"Naz Reid","nickname":"Timberwolves","pos_main":"PF","fantasy_pts":"12.53","avg_pts":"16.93","fpts_diff":"-4.40","date":"2022-02-28","salary":"3,500","salary_diff":"3305","salary_diff_percentage":"1694.9","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3305 (1694.9%)<\\/td>","salary_change":"1694.9"},',
#  '"player_id":"1257431","player_name":"KJ Martin Jr.","nickname":"Rockets","pos_main":"PF","fantasy_pts":"17.03","avg_pts":"17.01","fpts_diff":"+0.02","date":"2022-02-28","salary":"3,700","salary_diff":"3487","salary_diff_percentage":"1637.1","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3487 (1637.1%)<\\/td>","salary_change":"1637.1"},',
#  '"player_id":"329670","player_name":"Wayne Ellington","nickname":"Lakers","pos_main":"SG","fantasy_pts":"6.24","avg_pts":"11.39","fpts_diff":"-5.15","date":"2022-02-28","salary":"4,800","salary_diff":"4477","salary_diff_percentage":"1386.1","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$4477 (1386.1%)<\\/td>","salary_change":"1386.1"},',
#  '"player_id":"1067852","player_name":"Jarred Vanderbilt","nickname":"Timberwolves","pos_main":"PF","fantasy_pts":"22.95","avg_pts":"24.21","fpts_diff":"-1.26","date":"2022-02-28","salary":"4,500","salary_diff":"4189","salary_diff_percentage":"1346.9","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$4189 (1346.9%)<\\/td>","salary_change":"1346.9"},',
#  '"player_id":"609081","player_name":"Damion Lee","nickname":"Warriors","pos_main":"SG","fantasy_pts":"11.44","avg_pts":"14.89","fpts_diff":"-3.45","date":"2022-02-28","salary":"3,200","salary_diff":"2975","salary_diff_percentage":"1322.2","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2975 (1322.2%)<\\/td>","salary_change":"1322.2"},',
#  '"player_id":"846499","player_name":"Kevon Looney","nickname":"Warriors","pos_main":"C","fantasy_pts":"24.76","avg_pts":"20.83","fpts_diff":"+3.93","date":"2022-02-28","salary":"4,500","salary_diff":"4174","salary_diff_percentage":"1280.4","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$4174 (1280.4%)<\\/td>","salary_change":"1280.4"},',
#  '"player_id":"1177013","player_name":"Jaden McDaniels","nickname":"Timberwolves","pos_main":"SF","fantasy_pts":"17.77","avg_pts":"19.08","fpts_diff":"-1.31","date":"2022-02-28","salary":"4,000","salary_diff":"3696","salary_diff_percentage":"1215.8","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3696 (1215.8%)<\\/td>","salary_change":"1215.8"},',
#  '"player_id":"1061682","player_name":"Nicolas Claxton","nickname":"Nets","pos_main":"C","fantasy_pts":"3.48","avg_pts":"19.84","fpts_diff":"-16.36","date":"2022-02-28","salary":"4,000","salary_diff":"3695","salary_diff_percentage":"1211.5","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3695 (1211.5%)<\\/td>","salary_change":"1211.5"},',
#  '"player_id":"787141","player_name":"David Nwaba","nickname":"Rockets","pos_main":"SF","fantasy_pts":"1.93","avg_pts":"12.97","fpts_diff":"-11.04","date":"2022-02-28","salary":"3,000","salary_diff":"2763","salary_diff_percentage":"1165.8","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2763 (1165.8%)<\\/td>","salary_change":"1165.8"},',
#  '"player_id":"844465","player_name":"Jordan McLaughlin","nickname":"Timberwolves","pos_main":"PG","fantasy_pts":"10.01","avg_pts":"10.29","fpts_diff":"-0.28","date":"2022-02-28","salary":"3,200","salary_diff":"2931","salary_diff_percentage":"1089.6","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2931 (1089.6%)<\\/td>","salary_change":"1089.6"},',
#  '"player_id":"601518","player_name":"Khem Birch","nickname":"Raptors","pos_main":"C","fantasy_pts":"13.69","avg_pts":"13.73","fpts_diff":"-0.04","date":"2022-02-28","salary":"3,200","salary_diff":"2929","salary_diff_percentage":"1080.8","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2929 (1080.8%)<\\/td>","salary_change":"1080.8"},',
#  '"player_id":"946878","player_name":"Malachi Flynn","nickname":"Raptors","pos_main":"PG","fantasy_pts":"15.98","avg_pts":"7.93","fpts_diff":"+8.05","date":"2022-02-28","salary":"3,100","salary_diff":"2835","salary_diff_percentage":"1069.8","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2835 (1069.8%)<\\/td>","salary_change":"1069.8"},',
#  '"player_id":"843265","player_name":"Svi Mykhailiuk","nickname":"Raptors","pos_main":"SG","fantasy_pts":"3.14","avg_pts":"10.32","fpts_diff":"-7.18","date":"2022-02-28","salary":"3,000","salary_diff":"2739","salary_diff_percentage":"1049.4","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2739 (1049.4%)<\\/td>","salary_change":"1049.4"},',
#  '"player_id":"601511","player_name":"Juan Toscano-Anderson","nickname":"Warriors","pos_main":"C","fantasy_pts":"5.97","avg_pts":"12.13","fpts_diff":"-6.16","date":"2022-02-28","salary":"3,000","salary_diff":"2734","salary_diff_percentage":"1027.8","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2734 (1027.8%)<\\/td>","salary_change":"1027.8"},',
#  '"player_id":"846407","player_name":"Gary Payton II","nickname":"Warriors","pos_main":"PG","fantasy_pts":"21.44","avg_pts":"16.03","fpts_diff":"+5.41","date":"2022-02-28","salary":"4,200","salary_diff":"3803","salary_diff_percentage":"957.9","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3803 (957.9%)<\\/td>","salary_change":"957.9"},',
#  '"player_id":"844331","player_name":"Stanley Johnson","nickname":"Lakers","pos_main":"SF","fantasy_pts":"11.68","avg_pts":"14.34","fpts_diff":"-2.66","date":"2022-02-28","salary":"4,200","salary_diff":"3772","salary_diff_percentage":"881.3","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3772 (881.3%)<\\/td>","salary_change":"881.3"},',
#  '"player_id":"1175124","player_name":"Precious Achiuwa","nickname":"Raptors","pos_main":"C","fantasy_pts":"20.49","avg_pts":"20.53","fpts_diff":"-0.04","date":"2022-02-28","salary":"4,000","salary_diff":"3589","salary_diff_percentage":"873.2","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3589 (873.2%)<\\/td>","salary_change":"873.2"},',
#  '"player_id":"941460","player_name":"Josh Okogie","nickname":"Timberwolves","pos_main":"SF","fantasy_pts":"1.24","avg_pts":"7.13","fpts_diff":"-5.89","date":"2022-02-28","salary":"3,000","salary_diff":"2682","salary_diff_percentage":"843.4","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2682 (843.4%)<\\/td>","salary_change":"843.4"},',
#  '"player_id":"1251666","player_name":"Scottie Barnes","nickname":"Raptors","pos_main":"SF","fantasy_pts":"32.64","avg_pts":"32.36","fpts_diff":"+0.28","date":"2022-02-28","salary":"6,000","salary_diff":"5320","salary_diff_percentage":"782.4","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$5320 (782.4%)<\\/td>","salary_change":"782.4"},',
#  '"player_id":"1089562","player_name":"Jaylen Nowell","nickname":"Timberwolves","pos_main":"PG","fantasy_pts":"3.47","avg_pts":"14.68","fpts_diff":"-11.21","date":"2022-02-28","salary":"3,000","salary_diff":"2659","salary_diff_percentage":"779.8","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2659 (779.8%)<\\/td>","salary_change":"779.8"},',
#  '"player_id":"506103","player_name":"Rodney McGruder","nickname":"Pistons","pos_main":"SF","fantasy_pts":"10.63","avg_pts":"9.63","fpts_diff":"+1.01","date":"2022-02-28","salary":"3,900","salary_diff":"3409","salary_diff_percentage":"694.3","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3409 (694.3%)<\\/td>","salary_change":"694.3"},',
#  '"player_id":"888431","player_name":"Garrison Mathews","nickname":"Rockets","pos_main":"SF","fantasy_pts":"11.74","avg_pts":"20.28","fpts_diff":"-8.54","date":"2022-02-28","salary":"3,600","salary_diff":"3143","salary_diff_percentage":"687.7","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3143 (687.7%)<\\/td>","salary_change":"687.7"},',
#  '"player_id":"845512","player_name":"Chris Chiozza","nickname":"Warriors","pos_main":"PG","fantasy_pts":"0.69","avg_pts":"6.85","fpts_diff":"-6.16","date":"2022-02-28","salary":"3,000","salary_diff":"2601","salary_diff_percentage":"651.9","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2601 (651.9%)<\\/td>","salary_change":"651.9"},',
#  '"player_id":"846639","player_name":"Yuta Watanabe","nickname":"Raptors","pos_main":"SG","fantasy_pts":"4.45","avg_pts":"11.30","fpts_diff":"-6.85","date":"2022-02-28","salary":"3,300","salary_diff":"2860","salary_diff_percentage":"650.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2860 (650.0%)<\\/td>","salary_change":"650.0"},',
#  '"player_id":"1271708","player_name":"Jonathan Kuminga","nickname":"Warriors","pos_main":"PF","fantasy_pts":"22.46","avg_pts":"14.13","fpts_diff":"+8.33","date":"2022-02-28","salary":"4,600","salary_diff":"3981","salary_diff_percentage":"643.1","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3981 (643.1%)<\\/td>","salary_change":"643.1"},',
#  '"player_id":"1232020","player_name":"Cameron Thomas","nickname":"Nets","pos_main":"SG","fantasy_pts":"23.44","avg_pts":"16.46","fpts_diff":"+6.98","date":"2022-02-28","salary":"5,000","salary_diff":"4302","salary_diff_percentage":"616.3","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$4302 (616.3%)<\\/td>","salary_change":"616.3"},',
#  '"player_id":"937667","player_name":"Frank Jackson","nickname":"Pistons","pos_main":"SG","fantasy_pts":"5.98","avg_pts":"16.22","fpts_diff":"-10.24","date":"2022-02-28","salary":"2,700","salary_diff":"2320","salary_diff_percentage":"610.5","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2320 (610.5%)<\\/td>","salary_change":"610.5"},',
#  '"player_id":"843997","player_name":"D.J. Wilson","nickname":"Raptors","pos_main":"PF","fantasy_pts":"3.47","avg_pts":"16.63","fpts_diff":"-13.16","date":"2022-02-28","salary":"3,000","salary_diff":"2576","salary_diff_percentage":"607.5","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2576 (607.5%)<\\/td>","salary_change":"607.5"},',
#  '"player_id":"698664","player_name":"Jake Layman","nickname":"Timberwolves","pos_main":"SF","fantasy_pts":"1.22","avg_pts":"4.46","fpts_diff":"-3.24","date":"2022-02-28","salary":"3,000","salary_diff":"2571","salary_diff_percentage":"599.3","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2571 (599.3%)<\\/td>","salary_change":"599.3"},',
#  '"player_id":"1323508","player_name":"Alperen Sengun","nickname":"Rockets","pos_main":"PF","fantasy_pts":"18.94","avg_pts":"21.13","fpts_diff":"-2.19","date":"2022-02-28","salary":"4,100","salary_diff":"3474","salary_diff_percentage":"555.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$3474 (555.0%)<\\/td>","salary_change":"555.0"},',
#  '"player_id":"1076674","player_name":"Bruno Fernando","nickname":"Rockets","pos_main":"C","fantasy_pts":"1.95","avg_pts":"2.92","fpts_diff":"-0.97","date":"2022-02-28","salary":"3,000","salary_diff":"2506","salary_diff_percentage":"507.3","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2506 (507.3%)<\\/td>","salary_change":"507.3"},',
#  '"player_id":"410764","player_name":"Kent Bazemore","nickname":"Lakers","pos_main":"SG","fantasy_pts":"2.44","avg_pts":"8.92","fpts_diff":"-6.48","date":"2022-02-28","salary":"1,500","salary_diff":"1243","salary_diff_percentage":"483.7","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$1243 (483.7%)<\\/td>","salary_change":"483.7"},',
#  '"player_id":"953887","player_name":"Nathan Knight","nickname":"Timberwolves","pos_main":"C","fantasy_pts":"1.07","avg_pts":"7.19","fpts_diff":"-6.12","date":"2022-02-28","salary":"3,000","salary_diff":"2484","salary_diff_percentage":"481.4","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2484 (481.4%)<\\/td>","salary_change":"481.4"},',
#  '"player_id":"1135006","player_name":"Kessler Edwards","nickname":"Nets","pos_main":"PF","fantasy_pts":"8.94","avg_pts":"15.44","fpts_diff":"-6.50","date":"2022-02-28","salary":"3,500","salary_diff":"2854","salary_diff_percentage":"441.8","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2854 (441.8%)<\\/td>","salary_change":"441.8"},',
#  '"player_id":"1231305","player_name":"Josh Christopher","nickname":"Rockets","pos_main":"SG","fantasy_pts":"15.42","avg_pts":"14.02","fpts_diff":"+1.40","date":"2022-02-28","salary":"3,300","salary_diff":"2678","salary_diff_percentage":"430.5","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2678 (430.5%)<\\/td>","salary_change":"430.5"},',
#  '"player_id":"886418","player_name":"Quinndary Weatherspoon","nickname":"Warriors","pos_main":"PG","fantasy_pts":"1.17","avg_pts":"5.40","fpts_diff":"-4.23","date":"2022-02-28","salary":"3,000","salary_diff":"2425","salary_diff_percentage":"421.7","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2425 (421.7%)<\\/td>","salary_change":"421.7"},',
#  '"player_id":"1231366","player_name":"Moses Moody","nickname":"Warriors","pos_main":"SG","fantasy_pts":"10.47","avg_pts":"6.33","fpts_diff":"+4.14","date":"2022-02-28","salary":"3,000","salary_diff":"2380","salary_diff_percentage":"383.9","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2380 (383.9%)<\\/td>","salary_change":"383.9"},',
#  '"player_id":"1243725","player_name":"Day\'Ron Sharpe","nickname":"Nets","pos_main":"C","fantasy_pts":"2.71","avg_pts":"14.45","fpts_diff":"-11.74","date":"2022-02-28","salary":"3,100","salary_diff":"2452","salary_diff_percentage":"378.4","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2452 (378.4%)<\\/td>","salary_change":"378.4"},',
#  '"player_id":"740339","player_name":"Sterling Brown","nickname":"Mavericks","pos_main":"SG","fantasy_pts":"1.20","avg_pts":"10.05","fpts_diff":"-8.85","date":"2022-02-28","salary":"1,500","salary_diff":"1186","salary_diff_percentage":"377.7","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$1186 (377.7%)<\\/td>","salary_change":"377.7"},',
#  '"player_id":"1134645","player_name":"David Duke","nickname":"Nets","pos_main":"SG","fantasy_pts":"5.69","avg_pts":"12.20","fpts_diff":"-6.51","date":"2022-02-28","salary":"3,000","salary_diff":"2355","salary_diff_percentage":"365.1","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2355 (365.1%)<\\/td>","salary_change":"365.1"},',
#  '"player_id":"1138668","player_name":"Dalano Banton","nickname":"Raptors","pos_main":"PG","fantasy_pts":"8.93","avg_pts":"9.53","fpts_diff":"-0.60","date":"2022-02-28","salary":"3,000","salary_diff":"2321","salary_diff_percentage":"341.8","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2321 (341.8%)<\\/td>","salary_change":"341.8"},',
#  '"player_id":"1175260","player_name":"Justin Champagnie","nickname":"Raptors","pos_main":"SF","fantasy_pts":"3.67","avg_pts":"6.03","fpts_diff":"-2.36","date":"2022-02-28","salary":"3,000","salary_diff":"2319","salary_diff_percentage":"340.5","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2319 (340.5%)<\\/td>","salary_change":"340.5"},',
#  '"player_id":"1067689","player_name":"Saben Lee","nickname":"Pistons","pos_main":"PG","fantasy_pts":"0.47","avg_pts":"13.68","fpts_diff":"-13.21","date":"2022-02-28","salary":"1,500","salary_diff":"1157","salary_diff_percentage":"337.3","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$1157 (337.3%)<\\/td>","salary_change":"337.3"},',
#  '"player_id":"953291","player_name":"Austin Reaves","nickname":"Lakers","pos_main":"PG","fantasy_pts":"14.11","avg_pts":"12.40","fpts_diff":"+1.71","date":"2022-02-28","salary":"2,700","salary_diff":"2061","salary_diff_percentage":"322.5","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$2061 (322.5%)<\\/td>","salary_change":"322.5"},',
#  '"player_id":"553331","player_name":"Boban Marjanovic","nickname":"Mavericks","pos_main":"C","fantasy_pts":"0.85","avg_pts":"7.09","fpts_diff":"-6.24","date":"2022-02-28","salary":"1,500","salary_diff":"1131","salary_diff_percentage":"306.5","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$1131 (306.5%)<\\/td>","salary_change":"306.5"},',
#  '"player_id":"1067672","player_name":"Isaiah Livers","nickname":"Pistons","pos_main":"PF","fantasy_pts":"10.18","avg_pts":"7.25","fpts_diff":"+2.93","date":"2022-02-28","salary":"2,100","salary_diff":"1483","salary_diff_percentage":"240.4","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$1483 (240.4%)<\\/td>","salary_change":"240.4"},',
#  '"player_id":"1193670","player_name":"Josh Green","nickname":"Mavericks","pos_main":"SF","fantasy_pts":"8.90","avg_pts":"10.48","fpts_diff":"-1.58","date":"2022-02-28","salary":"1,500","salary_diff":"993","salary_diff_percentage":"195.9","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$993 (195.9%)<\\/td>","salary_change":"195.9"},',
#  '"player_id":"1061057","player_name":"Luka Garza","nickname":"Pistons","pos_main":"C","fantasy_pts":"0.71","avg_pts":"10.61","fpts_diff":"-9.90","date":"2022-02-28","salary":"1,500","salary_diff":"885","salary_diff_percentage":"143.9","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$885 (143.9%)<\\/td>","salary_change":"143.9"},',
#  '"player_id":"1061552","player_name":"Chris Smith","nickname":"Pistons","pos_main":"SG","fantasy_pts":"1.31","avg_pts":"-","fpts_diff":"-","date":"2022-02-28","salary":"1,500","salary_diff":"882","salary_diff_percentage":"142.7","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$882 (142.7%)<\\/td>","salary_change":"142.7"},',
#  '"player_id":"937647","player_name":"Jayson Tatum","nickname":"Celtics","pos_main":"F","fantasy_pts":"46.41","avg_pts":"46.15","fpts_diff":"+0.26","date":"2022-02-27","salary":"17","salary_diff":"-14083","salary_diff_percentage":"-99.9","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$14083 (-99.9%)<\\/td>","salary_change":"-99.9"},',
#  '"player_id":"1060978","player_name":"Trae Young","nickname":"Hawks","pos_main":"G","fantasy_pts":"48.06","avg_pts":"49.14","fpts_diff":"-1.08","date":"2022-02-26","salary":"10","salary_diff":"-9490","salary_diff_percentage":"-99.9","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$9490 (-99.9%)<\\/td>","salary_change":"-99.9"},',
#  '"player_id":"883436","player_name":"Jaylen Brown","nickname":"Celtics","pos_main":"F","fantasy_pts":"39.87","avg_pts":"39.40","fpts_diff":"+0.47","date":"2022-02-27","salary":"41","salary_diff":"-13459","salary_diff_percentage":"-99.7","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$13459 (-99.7%)<\\/td>","salary_change":"-99.7"},',
#  '"player_id":"830647","player_name":"Clint Capela","nickname":"Hawks","pos_main":"C","fantasy_pts":"29.62","avg_pts":"32.35","fpts_diff":"-2.73","date":"2022-02-26","salary":"48","salary_diff":"-6552","salary_diff_percentage":"-99.3","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$6552 (-99.3%)<\\/td>","salary_change":"-99.3"},',
#  '"player_id":"697132","player_name":"Marcus Smart","nickname":"Celtics","pos_main":"G","fantasy_pts":"28.80","avg_pts":"28.70","fpts_diff":"+0.10","date":"2022-02-27","salary":"77","salary_diff":"-10123","salary_diff_percentage":"-99.2","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$10123 (-99.2%)<\\/td>","salary_change":"-99.2"},',
#  '"player_id":"280587","player_name":"Al Horford","nickname":"Celtics","pos_main":"C","fantasy_pts":"26.98","avg_pts":"28.82","fpts_diff":"-1.84","date":"2022-02-27","salary":"83","salary_diff":"-9517","salary_diff_percentage":"-99.1","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$9517 (-99.1%)<\\/td>","salary_change":"-99.1"},',
#  '"player_id":"462444","player_name":"Reggie Jackson","nickname":"Clippers","pos_main":"G","fantasy_pts":"38.12","avg_pts":"29.90","fpts_diff":"+8.22","date":"2022-02-27","salary":"188","salary_diff":"-14212","salary_diff_percentage":"-98.7","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$14212 (-98.7%)<\\/td>","salary_change":"-98.7"},',
#  '"player_id":"469089","player_name":"Marcus Morris Sr.","nickname":"Clippers","pos_main":"F","fantasy_pts":"28.81","avg_pts":"27.13","fpts_diff":"+1.69","date":"2022-02-27","salary":"157","salary_diff":"-11543","salary_diff_percentage":"-98.7","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$11543 (-98.7%)<\\/td>","salary_change":"-98.7"},',
#  '"player_id":"796009","player_name":"Derrick White","nickname":"Celtics","pos_main":"G","fantasy_pts":"22.67","avg_pts":"30.06","fpts_diff":"-7.39","date":"2022-02-27","salary":"117","salary_diff":"-8883","salary_diff_percentage":"-98.7","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$8883 (-98.7%)<\\/td>","salary_change":"-98.7"},',
#  '"player_id":"830648","player_name":"Bogdan Bogdanovic","nickname":"Hawks","pos_main":"F","fantasy_pts":"28.14","avg_pts":"26.02","fpts_diff":"+2.12","date":"2022-02-26","salary":"89","salary_diff":"-6011","salary_diff_percentage":"-98.5","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$6011 (-98.5%)<\\/td>","salary_change":"-98.5"},',
#  '"player_id":"525052","player_name":"Robert Covington","nickname":"Clippers","pos_main":"F","fantasy_pts":"19.68","avg_pts":"22.55","fpts_diff":"-2.87","date":"2022-02-27","salary":"109","salary_diff":"-6791","salary_diff_percentage":"-98.4","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$6791 (-98.4%)<\\/td>","salary_change":"-98.4"},',
#  '"player_id":"844476","player_name":"Kyle Kuzma","nickname":"Wizards","pos_main":"F","fantasy_pts":"44.07","avg_pts":"36.31","fpts_diff":"+7.76","date":"2022-02-26","salary":"152","salary_diff":"-8648","salary_diff_percentage":"-98.3","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$8648 (-98.3%)<\\/td>","salary_change":"-98.3"},',
#  '"player_id":"954390","player_name":"Robert Williams","nickname":"Celtics","pos_main":"C","fantasy_pts":"32.16","avg_pts":"31.44","fpts_diff":"+0.73","date":"2022-02-27","salary":"199","salary_diff":"-10901","salary_diff_percentage":"-98.2","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$10901 (-98.2%)<\\/td>","salary_change":"-98.2"},',
#  '"player_id":"920093","player_name":"Ivica Zubac","nickname":"Clippers","pos_main":"C","fantasy_pts":"30.36","avg_pts":"24.70","fpts_diff":"+5.66","date":"2022-02-27","salary":"189","salary_diff":"-10011","salary_diff_percentage":"-98.1","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$10011 (-98.1%)<\\/td>","salary_change":"-98.1"},',
#  '"player_id":"1066725","player_name":"Daniel Theis","nickname":"Celtics","pos_main":"C","fantasy_pts":"6.28","avg_pts":"17.56","fpts_diff":"-11.28","date":"2022-02-27","salary":"160","salary_diff":"-6140","salary_diff_percentage":"-97.5","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$6140 (-97.5%)<\\/td>","salary_change":"-97.5"},',
#  '"player_id":"896601","player_name":"Thomas Bryant","nickname":"Wizards","pos_main":"C","fantasy_pts":"19.30","avg_pts":"15.89","fpts_diff":"+3.41","date":"2022-02-26","salary":"119","salary_diff":"-4481","salary_diff_percentage":"-97.4","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$4481 (-97.4%)<\\/td>","salary_change":"-97.4"},',
#  '"player_id":"456448","player_name":"Danilo Gallinari","nickname":"Hawks","pos_main":"F","fantasy_pts":"24.94","avg_pts":"20.23","fpts_diff":"+4.71","date":"2022-02-26","salary":"137","salary_diff":"-4963","salary_diff_percentage":"-97.3","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$4963 (-97.3%)<\\/td>","salary_change":"-97.3"},',
#  '"player_id":"944785","player_name":"Kevin Huerter","nickname":"Hawks","pos_main":"G","fantasy_pts":"21.61","avg_pts":"22.04","fpts_diff":"-0.43","date":"2022-02-26","salary":"127","salary_diff":"-4373","salary_diff_percentage":"-97.2","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$4373 (-97.2%)<\\/td>","salary_change":"-97.2"},',
#  '"player_id":"456451","player_name":"Nicolas Batum","nickname":"Clippers","pos_main":"F","fantasy_pts":"17.57","avg_pts":"20.40","fpts_diff":"-2.83","date":"2022-02-27","salary":"200","salary_diff":"-6400","salary_diff_percentage":"-97.0","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$6400 (-97.0%)<\\/td>","salary_change":"-97.0"},',
#  '"player_id":"879504","player_name":"Terance Mann","nickname":"Clippers","pos_main":"F","fantasy_pts":"27.06","avg_pts":"22.75","fpts_diff":"+4.31","date":"2022-02-27","salary":"357","salary_diff":"-11643","salary_diff_percentage":"-97.0","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$11643 (-97.0%)<\\/td>","salary_change":"-97.0"},',
#  '"player_id":"955893","player_name":"Rui Hachimura","nickname":"Wizards","pos_main":"F","fantasy_pts":"18.77","avg_pts":"16.14","fpts_diff":"+2.63","date":"2022-02-26","salary":"134","salary_diff":"-3866","salary_diff_percentage":"-96.7","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$3866 (-96.7%)<\\/td>","salary_change":"-96.7"},',
#  '"player_id":"942857","player_name":"De\'Andre Hunter","nickname":"Hawks","pos_main":"F","fantasy_pts":"23.15","avg_pts":"20.85","fpts_diff":"+2.30","date":"2022-02-26","salary":"151","salary_diff":"-4249","salary_diff_percentage":"-96.6","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$4249 (-96.6%)<\\/td>","salary_change":"-96.6"},',
#  '"player_id":"1057004","player_name":"Isaiah Hartenstein","nickname":"Clippers","pos_main":"F","fantasy_pts":"19.01","avg_pts":"19.21","fpts_diff":"-0.20","date":"2022-02-27","salary":"340","salary_diff":"-8060","salary_diff_percentage":"-96.0","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$8060 (-96.0%)<\\/td>","salary_change":"-96.0"},',
#  '"player_id":"887661","player_name":"Luke Kennard","nickname":"Clippers","pos_main":"G","fantasy_pts":"20.81","avg_pts":"21.99","fpts_diff":"-1.18","date":"2022-02-27","salary":"345","salary_diff":"-7755","salary_diff_percentage":"-95.7","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$7755 (-95.7%)<\\/td>","salary_change":"-95.7"},',
#  '"player_id":"329873","player_name":"Ish Smith","nickname":"Wizards","pos_main":"G","fantasy_pts":"19.74","avg_pts":"13.19","fpts_diff":"+6.55","date":"2022-02-26","salary":"183","salary_diff":"-4017","salary_diff_percentage":"-95.6","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$4017 (-95.6%)<\\/td>","salary_change":"-95.6"},',
#  '"player_id":"744102","player_name":"Delon Wright","nickname":"Hawks","pos_main":"G","fantasy_pts":"13.33","avg_pts":"13.92","fpts_diff":"-0.59","date":"2022-02-26","salary":"170","salary_diff":"-3130","salary_diff_percentage":"-94.8","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$3130 (-94.8%)<\\/td>","salary_change":"-94.8"},',
#  '"player_id":"1257422","player_name":"Deni Avdija","nickname":"Wizards","pos_main":"G","fantasy_pts":"23.59","avg_pts":"19.43","fpts_diff":"+4.17","date":"2022-02-26","salary":"278","salary_diff":"-4722","salary_diff_percentage":"-94.4","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$4722 (-94.4%)<\\/td>","salary_change":"-94.4"},',
#  '"player_id":"602730","player_name":"Kentavious Caldwell-Pope","nickname":"Wizards","pos_main":"G","fantasy_pts":"24.67","avg_pts":"21.93","fpts_diff":"+2.74","date":"2022-02-26","salary":"249","salary_diff":"-4151","salary_diff_percentage":"-94.3","salary_change_html":"<td class=\\"width-15 red\\" id=\\"salary-col\\">-$4151 (-94.3%)<\\/td>","salary_change":"-94.3"},',
# ...
#  '"player_id":"843805","player_name":"Kelan Martin","nickname":"Celtics","pos_main":"SF","fantasy_pts":"2.44","avg_pts":"11.40","fpts_diff":"-8.96","date":"2022-02-27","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"920091","player_name":"Timothe Luwawu","nickname":"Hawks","pos_main":"SF","fantasy_pts":"1.53","avg_pts":"7.49","fpts_diff":"-5.96","date":"2022-02-26","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"922378","player_name":"Sam Hauser","nickname":"Celtics","pos_main":"PF","fantasy_pts":"1.65","avg_pts":"3.43","fpts_diff":"-1.78","date":"2022-02-27","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"922397","player_name":"Malik Fitts","nickname":"Celtics","pos_main":"PF","fantasy_pts":"0.95","avg_pts":"2.15","fpts_diff":"-1.20","date":"2022-02-27","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"948123","player_name":"Skylar Mays","nickname":"Hawks","pos_main":"SG","fantasy_pts":"2.01","avg_pts":"6.04","fpts_diff":"-4.03","date":"2022-02-26","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1066725","player_name":"Daniel Theis","nickname":"Celtics","pos_main":"PF","fantasy_pts":"6.33","avg_pts":"17.44","fpts_diff":"-11.11","date":"2022-02-27","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1067854","player_name":"Kevin Knox","nickname":"Hawks","pos_main":"SF","fantasy_pts":"4.69","avg_pts":"5.43","fpts_diff":"-0.74","date":"2022-02-26","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"698664","player_name":"Jake Layman","nickname":"Timberwolves","pos_main":"SF","fantasy_pts":"1.22","avg_pts":"4.60","fpts_diff":"-3.38","date":"2022-02-28","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"845512","player_name":"Chris Chiozza","nickname":"Warriors","pos_main":"PG","fantasy_pts":"0.66","avg_pts":"6.40","fpts_diff":"-5.74","date":"2022-02-27","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"953887","player_name":"Nathan Knight","nickname":"Timberwolves","pos_main":"PF","fantasy_pts":"1.07","avg_pts":"7.17","fpts_diff":"-6.10","date":"2022-02-28","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"603106","player_name":"Rodney Hood","nickname":"Clippers","pos_main":"SG","fantasy_pts":"1.17","avg_pts":"7.27","fpts_diff":"-6.10","date":"2022-02-27","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1057004","player_name":"Isaiah Hartenstein","nickname":"Clippers","pos_main":"PF","fantasy_pts":"19.85","avg_pts":"20.19","fpts_diff":"-0.34","date":"2022-02-27","salary":"5,800","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1076674","player_name":"Bruno Fernando","nickname":"Rockets","pos_main":"PF","fantasy_pts":"1.95","avg_pts":"2.83","fpts_diff":"-0.88","date":"2022-02-27","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1076209","player_name":"Marvin Bagley","nickname":"Pistons","pos_main":"PF","fantasy_pts":"11.19","avg_pts":"20.07","fpts_diff":"-8.88","date":"2022-02-27","salary":"4,200","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1174858","player_name":"Vernon Carey","nickname":"Wizards","pos_main":"PF","fantasy_pts":"1.50","avg_pts":"3.20","fpts_diff":"-1.70","date":"2022-02-26","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"844331","player_name":"Stanley Johnson","nickname":"Lakers","pos_main":"SF","fantasy_pts":"11.73","avg_pts":"14.74","fpts_diff":"-3.01","date":"2022-02-27","salary":"7,000","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"659772","player_name":"Tomas Satoransky","nickname":"Wizards","pos_main":"PG","fantasy_pts":"3.74","avg_pts":"9.24","fpts_diff":"-5.50","date":"2022-02-26","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1134645","player_name":"David Duke","nickname":"Nets","pos_main":"SG","fantasy_pts":"5.63","avg_pts":"12.42","fpts_diff":"-6.79","date":"2022-02-28","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1138668","player_name":"Dalano Banton","nickname":"Raptors","pos_main":"PF","fantasy_pts":"8.96","avg_pts":"9.48","fpts_diff":"-0.52","date":"2022-02-28","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1175260","player_name":"Justin Champagnie","nickname":"Raptors","pos_main":"SF","fantasy_pts":"3.65","avg_pts":"6.01","fpts_diff":"-2.36","date":"2022-02-28","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1243725","player_name":"Day\'Ron Sharpe","nickname":"Nets","pos_main":"PF","fantasy_pts":"2.71","avg_pts":"14.39","fpts_diff":"-11.68","date":"2022-02-28","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1067672","player_name":"Isaiah Livers","nickname":"Pistons","pos_main":"PF","fantasy_pts":"10.15","avg_pts":"7.45","fpts_diff":"+2.70","date":"2022-02-27","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1061057","player_name":"Luka Garza","nickname":"Pistons","pos_main":"C","fantasy_pts":"0.69","avg_pts":"10.29","fpts_diff":"-9.60","date":"2022-02-27","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1061552","player_name":"Chris Smith","nickname":"Pistons","pos_main":"PF","fantasy_pts":"1.30","avg_pts":"-","fpts_diff":"-","date":"2022-02-27","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1067689","player_name":"Saben Lee","nickname":"Pistons","pos_main":"PG","fantasy_pts":"0.45","avg_pts":"14.22","fpts_diff":"-13.77","date":"2022-02-27","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1076297","player_name":"Jamorko Pickett","nickname":"Pistons","pos_main":"SF","fantasy_pts":"0.45","avg_pts":"2.55","fpts_diff":"-2.10","date":"2022-02-27","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"886418","player_name":"Quinndary Weatherspoon","nickname":"Warriors","pos_main":"SG","fantasy_pts":"1.15","avg_pts":"5.44","fpts_diff":"-4.29","date":"2022-02-27","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"},',
#  '"player_id":"1271713","player_name":"Isaiah Todd","nickname":"Wizards","pos_main":"PF","fantasy_pts":"1.21","avg_pts":"4.35","fpts_diff":"-3.14","date":"2022-02-26","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"}];\n        this.players_ya = [];\n        this.current_site = \'dk\';\n      }\n      Model.prototype = ',
#  '\n        determineSortFunction: function(type)',
#  "\n          var self = this;\n          if(type=='player_name'||type=='pos_main')",
#  "\n            self.currentSort = type;\n            self.sortFunction = self.alph_sort;\n            return self.sortFunction;\n          }else if(type=='salary'||type=='salary_diff')",
#  '\n            self.currentSort = type;\n            self.sortFunction = self.salary_sort;\n            return self.sortFunction;\n          }else',
#  '\n            self.currentSort = type;\n            self.sortFunction = self.float_sort;\n            return self.sortFunction;\n          }\n        },\n        alph_sort: function(key,a,b)',
#  '\n          if((a[key]) < (b[key])) return -1;\n          if((a[key]) > (b[key])) return 1;\n          return 0;\n        },\n        time_sort: function(key,a,b)',
#  "\n          if((a['date']) < (b['date'])) return -1;\n          if((a['date']) > (b['date'])) return 1;\n          return 0;\n        },\n        salary_sort: function(key,a,b)",
#  '\n          if(parseInt(a[key]) < parseInt(b[key])) return -1;\n          if(parseInt(a[key]) > parseInt(b[key])) return 1;\n          return 0;\n        },\n        float_sort: function(key,a,b)',
#  '\n          if(parseFloat(a[key]) < parseFloat(b[key])) return -1;\n          if(parseFloat(a[key]) > parseFloat(b[key])) return 1;\n          return 0;\n        },\n        default_sort: function(a,b)',
#  "\n          if(parseFloat(a[this.currentSite+'_fpts']) < parseFloat(b[this.currentSite+'_fpts'])) return -1;\n          if(parseFloat(a[this.currentSite+'_fpts']) > parseFloat(b[this.currentSite+'_fpts'])) return 1;\n          return 0;\n        }\n      }\n\n      function View()",
#  '\n\n      }\n      View.prototype = ',
#  '\n        fillPlayerPool: function(players)',
#  "\n          var self = this;\n          $('.stat-table').empty();\n          $.each(players,function(key,value)",
#  '\n            var player_string = \'<tr class="salary-row">\'+\n                                \'<td id="salary-col" class="width-10 text-left">\'+value.pos_main+\'</td>\'+\n                                \'<td id="salary-col" class="width-20 text-left "><img src="/style/assets/img/nba/teams/\'+value.nickname.replace(" ","_").toLowerCase()+\'.png" height="20px" class="pad-right-5"> \'+value.player_name+\'</td>\'+\n                                \'<td class="width-15" id="salary-col">$\'+value.salary+\'</td>\'+\n                                \'<td class="width-15 \'+self.determineColor(parseInt(value.salary_diff))+\'" id="salary-col">\'+self.formatSalary(parseInt(value.salary_diff))+\' (\'+value.salary_diff_percentage+\'%)</td>\'+\n                                \'<td class="width-15" id="salary-col">\'+value.fantasy_pts+\'</td>\'+\n                                \'<td class="width-15" id="salary-col">\'+value.avg_pts+\'</td>\'+\n                                \'<td class="width-10" id="salary-col">\'+value.fpts_diff+\'</td></tr>\';\n            $(\'.stat-table\').append(player_string);\n          })\n        },\n        determineColor: function(salary)',
#  '\n          if(salary<0)',
#  "\n            return 'red';\n          }else",
#  "\n            return 'green';\n          }\n        },\n        formatSalary: function(salary)",
#  '\n          if(salary>0)',
#  "\n            return '+$'+salary;\n          }else",
#  "\n            return '-$'+(salary*-1);\n          }\n        }\n      }\n\n      function Controller()",
#  '\n        this.model = new Model();\n        this.view = new View();\n      }\n      Controller.prototype = ',
#  '\n        fillPlayerPool: function()',
#  "\n          this.view.fillPlayerPool(this.model['players_'+this.model.current_site])\n        },\n        siteListener: function()",
#  "\n          var self = this;\n          $('.fantasySite').click(function(e)",
#  "\n            e.preventDefault();\n            self.model.current_site = $(this).attr('site');\n            $('.fantasy-parent').children().removeClass('active activeSite');\n            $(this).addClass('active activeSite');\n            self.fillPlayerPool();\n          });\n        },\n        sortListener: function()",
#  "\n          var self = this;\n          $(document).on('click','.stat-sort',function()",
#  "\n            var sortFunction = self.model.determineSortFunction($(this).attr('type'));\n            if ($(this).hasClass('sorted'))",
#  "\n              $(this).removeClass('sorted');\n              $(this).addClass('reverseSorted');\n              var sortBy = 'reverse';\n            } else if ($(this).hasClass('reverseSorted'))",
#  "\n              $(this).removeClass('reverseSorted');\n              $('.sortTriggers').children().removeClass('sorted');\n              var sortBy = 'unsort';\n            } else ",
#  "\n              $('.sortTriggers').children().removeClass('sorted');\n              $('.sortTriggers').children().removeClass('reverseSorted');\n              $(this).addClass('sorted');\n              var sortBy = 'sort';\n            }\n            self.performSort(sortFunction, sortBy);\n          })\n        },\n        performSort: function(sortFunction, sortBy)",
#  "\n          var self = this;\n          if (sortBy == 'sort')",
#  "\n            self.model['players_'+self.model.current_site].sort(sortFunction.bind(null, self.model.currentSort));\n          } else if (sortBy == 'reverse')",
#  "\n            self.model['players_'+self.model.current_site].sort(sortFunction.bind(null, self.model.currentSort)).reverse();\n          } else if (sortBy == 'unsort')",
#  "\n            self.model['players_'+self.model.current_site].sort(self.model.float_sort.bind(null, self.model.currentSite+'_fpts')).reverse();\n          }\n          self.fillPlayerPool();\n        }\n      }\n\n      $(document).ready(function()",
#  '\n        var controller = new Controller();\n        controller.fillPlayerPool();\n        controller.siteListener();\n        controller.sortListener();\n      })\n\n\n\n    ']

# %%
table[-36]
# Out:
# '"player_id":"1271713","player_name":"Isaiah Todd","nickname":"Wizards","pos_main":"PF","fantasy_pts":"1.21","avg_pts":"4.35","fpts_diff":"-3.14","date":"2022-02-26","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"}];\n        this.players_ya = [];\n        this.current_site = \'dk\';\n      }\n      Model.prototype = '

# %%
table[-35]
# Out:
# '\n        determineSortFunction: function(type)'

# %%
table[2]
# Out:
# '"player_id":"1121277","player_name":"Luka Doncic","nickname":"Mavericks","pos_main":"PG","fantasy_pts":"62.69","avg_pts":"56.41","fpts_diff":"+6.28","date":"2022-02-28","salary":"21,900","salary_diff":"21899","salary_diff_percentage":"2189900.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$21899 (2189900.0%)<\\/td>","salary_change":"2189900.0"},'

# %%
table[1]
# Out:
# '\n        this.players_dk = ['

# %%
table = table[2:-35]

# %%
table[0]
# Out:
# '"player_id":"1121277","player_name":"Luka Doncic","nickname":"Mavericks","pos_main":"PG","fantasy_pts":"62.69","avg_pts":"56.41","fpts_diff":"+6.28","date":"2022-02-28","salary":"21,900","salary_diff":"21899","salary_diff_percentage":"2189900.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$21899 (2189900.0%)<\\/td>","salary_change":"2189900.0"},'

# %%
table[-1]
# Out:
# '"player_id":"1271713","player_name":"Isaiah Todd","nickname":"Wizards","pos_main":"PF","fantasy_pts":"1.21","avg_pts":"4.35","fpts_diff":"-3.14","date":"2022-02-26","salary":"3,500","salary_diff":"0","salary_diff_percentage":"0.0","salary_change_html":"<td class=\\"width-15 green\\" id=\\"salary-col\\">+$0 (0.0%)<\\/td>","salary_change":"0.0"}];\n        this.players_ya = [];\n        this.current_site = \'dk\';\n      }\n      Model.prototype = '

# %%
import re
def get_name_position_and_salary(player_info: list) -> dict:
    def convert_salary_float(salary):
        if "," in salary:
            salary = salary.replace(',', '')
        return float(salary)

    try:
        player_name = re.search('"player_name":"[\w].+[\w][",]', player_info)[0].split(':')[1].split(',')[0]
        position = re.search('"pos_main":"[\w]*"', player_info)[0].split(':')[1][1:-1]
        salary = convert_salary_float(re.search('"salary":"[\w]*[,]*[\w]*"', player_info)[0].split(':')[1][1:-1])
    except:
        print(f"It was not possible to get player's info. \nInput: \n{player_info}")

    return({'player_name': player_name, 'position': position, 'salary': salary})
    
get_name_position_and_salary(table[-1])
# Out:
# {'player_name': '"Isaiah Todd"', 'position': 'PF', 'salary': 3500.0}

# %%
position_and_salary = [get_name_position_and_salary(entry) for entry in table]
position_and_salary
# Out:
# [{'player_name': '"Luka Doncic"', 'position': 'PG', 'salary': 21900.0},
#  {'player_name': '"LeBron James"', 'position': 'SF', 'salary': 20700.0},
#  {'player_name': '"Stephen Curry"', 'position': 'PG', 'salary': 10800.0},
#  {'player_name': '"Russell Westbrook"', 'position': 'PG', 'salary': 15600.0},
#  {'player_name': '"Karl-Anthony Towns"', 'position': 'C', 'salary': 10100.0},
#  {'player_name': '"Pascal Siakam"', 'position': 'PF', 'salary': 8900.0},
#  {'player_name': '"Fred VanVleet"', 'position': 'PG', 'salary': 8500.0},
#  {'player_name': '"Andre Drummond"', 'position': 'C', 'salary': 6900.0},
#  {'player_name': '"Spencer Dinwiddie"', 'position': 'PG', 'salary': 11100.0},
#  {'player_name': '"D\'Angelo Russell"', 'position': 'PG', 'salary': 7600.0},
#  {'player_name': '"Christian Wood"', 'position': 'C', 'salary': 8100.0},
#  {'player_name': '"Cade Cunningham"', 'position': 'SG', 'salary': 14400.0},
#  {'player_name': '"Jerami Grant"', 'position': 'PF', 'salary': 12300.0},
#  {'player_name': '"Anthony Edwards"', 'position': 'SG', 'salary': 7400.0},
#  {'player_name': '"Andrew Wiggins"', 'position': 'SF', 'salary': 6200.0},
#  {'player_name': '"Dennis Schroder"', 'position': 'PG', 'salary': 5900.0},
#  {'player_name': '"Saddiq Bey"', 'position': 'SF', 'salary': 12900.0},
#  {'player_name': '"Kelly Olynyk"', 'position': 'PF', 'salary': 9600.0},
#  {'player_name': '"Jalen Brunson"', 'position': 'PG', 'salary': 12600.0},
#  {'player_name': '"Kevin Porter Jr."', 'position': 'PG', 'salary': 6000.0},
#  {'player_name': '"LaMarcus Aldridge"', 'position': 'C', 'salary': 4500.0},
#  {'player_name': '"Carmelo Anthony"', 'position': 'PF', 'salary': 8700.0},
#  {'player_name': '"Dorian Finney-Smith"', 'position': 'SF', 'salary': 9300.0},
#  {'player_name': '"Jalen Green"', 'position': 'PG', 'salary': 5500.0},
#  {'player_name': '"Marvin Bagley III"', 'position': 'PF', 'salary': 5700.0},
#  {'player_name': '"Isaiah Stewart"', 'position': 'C', 'salary': 9900.0},
#  {'player_name': '"Jae\'Sean Tate"', 'position': 'PF', 'salary': 6100.0},
#  {'player_name': '"Goran Dragic"', 'position': 'PG', 'salary': 4100.0},
#  {'player_name': '"Bruce Brown"', 'position': 'SF', 'salary': 5400.0},
#  {'player_name': '"Malik Monk"', 'position': 'PG', 'salary': 8400.0},
#  {'player_name': '"Seth Curry"', 'position': 'SG', 'salary': 6400.0},
#  {'player_name': '"Eric Gordon"', 'position': 'SG', 'salary': 4600.0},
#  {'player_name': '"Thaddeus Young"', 'position': 'PF', 'salary': 3700.0},
#  {'player_name': '"Reggie Bullock"', 'position': 'SG', 'salary': 8100.0},
#  {'player_name': '"Dwight Howard"', 'position': 'C', 'salary': 7500.0},
#  {'player_name': '"Maxi Kleber"', 'position': 'PF', 'salary': 7200.0},
#  {'player_name': '"Gary Trent Jr."', 'position': 'SG', 'salary': 6400.0},
#  {'player_name': '"Talen Horton-Tucker"', 'position': 'SG', 'salary': 7800.0},
#  {'player_name': '"Malik Beasley"', 'position': 'SG', 'salary': 3300.0},
#  {'player_name': '"Chris Boucher"', 'position': 'PF', 'salary': 4300.0},
#  {'player_name': '"Killian Hayes"', 'position': 'PG', 'salary': 6000.0},
#  {'player_name': '"Davis Bertans"', 'position': 'PF', 'salary': 5100.0},
#  {'player_name': '"Cory Joseph"', 'position': 'PG', 'salary': 6600.0},
#  {'player_name': '"Blake Griffin"', 'position': 'PF', 'salary': 3900.0},
#  {'player_name': '"Jordan Poole"', 'position': 'PG', 'salary': 5200.0},
#  {'player_name': '"Otto Porter Jr."', 'position': 'SF', 'salary': 4100.0},
#  {'player_name': '"Dwight Powell"', 'position': 'C', 'salary': 6600.0},
#  {'player_name': '"Patrick Beverley"', 'position': 'PG', 'salary': 5000.0},
#  {'player_name': '"Patty Mills"', 'position': 'SG', 'salary': 4600.0},
#  {'player_name': '"James Johnson"', 'position': 'PF', 'salary': 4300.0},
#  {'player_name': '"Trevor Ariza"', 'position': 'PF', 'salary': 3300.0},
#  {'player_name': '"Taurean Prince"', 'position': 'SF', 'salary': 3600.0},
#  {'player_name': '"Nemanja Bjelica"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"Naz Reid"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"KJ Martin Jr."', 'position': 'PF', 'salary': 3700.0},
#  {'player_name': '"Wayne Ellington"', 'position': 'SG', 'salary': 4800.0},
#  {'player_name': '"Jarred Vanderbilt"', 'position': 'PF', 'salary': 4500.0},
#  {'player_name': '"Damion Lee"', 'position': 'SG', 'salary': 3200.0},
#  {'player_name': '"Kevon Looney"', 'position': 'C', 'salary': 4500.0},
#  {'player_name': '"Jaden McDaniels"', 'position': 'SF', 'salary': 4000.0},
#  {'player_name': '"Nicolas Claxton"', 'position': 'C', 'salary': 4000.0},
#  {'player_name': '"David Nwaba"', 'position': 'SF', 'salary': 3000.0},
#  {'player_name': '"Jordan McLaughlin"', 'position': 'PG', 'salary': 3200.0},
#  {'player_name': '"Khem Birch"', 'position': 'C', 'salary': 3200.0},
#  {'player_name': '"Malachi Flynn"', 'position': 'PG', 'salary': 3100.0},
#  {'player_name': '"Svi Mykhailiuk"', 'position': 'SG', 'salary': 3000.0},
#  {'player_name': '"Juan Toscano-Anderson"', 'position': 'C', 'salary': 3000.0},
#  {'player_name': '"Gary Payton II"', 'position': 'PG', 'salary': 4200.0},
#  {'player_name': '"Stanley Johnson"', 'position': 'SF', 'salary': 4200.0},
#  {'player_name': '"Precious Achiuwa"', 'position': 'C', 'salary': 4000.0},
#  {'player_name': '"Josh Okogie"', 'position': 'SF', 'salary': 3000.0},
#  {'player_name': '"Scottie Barnes"', 'position': 'SF', 'salary': 6000.0},
#  {'player_name': '"Jaylen Nowell"', 'position': 'PG', 'salary': 3000.0},
#  {'player_name': '"Rodney McGruder"', 'position': 'SF', 'salary': 3900.0},
#  {'player_name': '"Garrison Mathews"', 'position': 'SF', 'salary': 3600.0},
#  {'player_name': '"Chris Chiozza"', 'position': 'PG', 'salary': 3000.0},
#  {'player_name': '"Yuta Watanabe"', 'position': 'SG', 'salary': 3300.0},
#  {'player_name': '"Jonathan Kuminga"', 'position': 'PF', 'salary': 4600.0},
#  {'player_name': '"Cameron Thomas"', 'position': 'SG', 'salary': 5000.0},
#  {'player_name': '"Frank Jackson"', 'position': 'SG', 'salary': 2700.0},
#  {'player_name': '"D.J. Wilson"', 'position': 'PF', 'salary': 3000.0},
#  {'player_name': '"Jake Layman"', 'position': 'SF', 'salary': 3000.0},
#  {'player_name': '"Alperen Sengun"', 'position': 'PF', 'salary': 4100.0},
#  {'player_name': '"Bruno Fernando"', 'position': 'C', 'salary': 3000.0},
#  {'player_name': '"Kent Bazemore"', 'position': 'SG', 'salary': 1500.0},
#  {'player_name': '"Nathan Knight"', 'position': 'C', 'salary': 3000.0},
#  {'player_name': '"Kessler Edwards"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"Josh Christopher"', 'position': 'SG', 'salary': 3300.0},
#  {'player_name': '"Quinndary Weatherspoon"',
#   'position': 'PG',
#   'salary': 3000.0},
#  {'player_name': '"Moses Moody"', 'position': 'SG', 'salary': 3000.0},
#  {'player_name': '"Day\'Ron Sharpe"', 'position': 'C', 'salary': 3100.0},
#  {'player_name': '"Sterling Brown"', 'position': 'SG', 'salary': 1500.0},
#  {'player_name': '"David Duke"', 'position': 'SG', 'salary': 3000.0},
#  {'player_name': '"Dalano Banton"', 'position': 'PG', 'salary': 3000.0},
#  {'player_name': '"Justin Champagnie"', 'position': 'SF', 'salary': 3000.0},
#  {'player_name': '"Saben Lee"', 'position': 'PG', 'salary': 1500.0},
#  {'player_name': '"Austin Reaves"', 'position': 'PG', 'salary': 2700.0},
#  {'player_name': '"Boban Marjanovic"', 'position': 'C', 'salary': 1500.0},
#  {'player_name': '"Isaiah Livers"', 'position': 'PF', 'salary': 2100.0},
#  {'player_name': '"Josh Green"', 'position': 'SF', 'salary': 1500.0},
#  {'player_name': '"Luka Garza"', 'position': 'C', 'salary': 1500.0},
#  {'player_name': '"Chris Smith"', 'position': 'SG', 'salary': 1500.0},
#  {'player_name': '"Jayson Tatum"', 'position': 'F', 'salary': 17.0},
#  {'player_name': '"Trae Young"', 'position': 'G', 'salary': 10.0},
#  {'player_name': '"Jaylen Brown"', 'position': 'F', 'salary': 41.0},
#  {'player_name': '"Clint Capela"', 'position': 'C', 'salary': 48.0},
#  {'player_name': '"Marcus Smart"', 'position': 'G', 'salary': 77.0},
#  {'player_name': '"Al Horford"', 'position': 'C', 'salary': 83.0},
#  {'player_name': '"Reggie Jackson"', 'position': 'G', 'salary': 188.0},
#  {'player_name': '"Marcus Morris Sr."', 'position': 'F', 'salary': 157.0},
#  {'player_name': '"Derrick White"', 'position': 'G', 'salary': 117.0},
#  {'player_name': '"Bogdan Bogdanovic"', 'position': 'F', 'salary': 89.0},
#  {'player_name': '"Robert Covington"', 'position': 'F', 'salary': 109.0},
#  {'player_name': '"Kyle Kuzma"', 'position': 'F', 'salary': 152.0},
#  {'player_name': '"Robert Williams"', 'position': 'C', 'salary': 199.0},
#  {'player_name': '"Ivica Zubac"', 'position': 'C', 'salary': 189.0},
#  {'player_name': '"Daniel Theis"', 'position': 'C', 'salary': 160.0},
#  {'player_name': '"Thomas Bryant"', 'position': 'C', 'salary': 119.0},
#  {'player_name': '"Danilo Gallinari"', 'position': 'F', 'salary': 137.0},
#  {'player_name': '"Kevin Huerter"', 'position': 'G', 'salary': 127.0},
#  {'player_name': '"Nicolas Batum"', 'position': 'F', 'salary': 200.0},
#  {'player_name': '"Terance Mann"', 'position': 'F', 'salary': 357.0},
#  {'player_name': '"Rui Hachimura"', 'position': 'F', 'salary': 134.0},
#  {'player_name': '"De\'Andre Hunter"', 'position': 'F', 'salary': 151.0},
#  {'player_name': '"Isaiah Hartenstein"', 'position': 'F', 'salary': 340.0},
#  {'player_name': '"Luke Kennard"', 'position': 'G', 'salary': 345.0},
#  {'player_name': '"Ish Smith"', 'position': 'G', 'salary': 183.0},
#  {'player_name': '"Delon Wright"', 'position': 'G', 'salary': 170.0},
#  {'player_name': '"Deni Avdija"', 'position': 'G', 'salary': 278.0},
#  {'player_name': '"Kentavious Caldwell-Pope"',
#   'position': 'G',
#   'salary': 249.0},
#  {'player_name': '"Raul Neto"', 'position': 'G', 'salary': 300.0},
#  {'player_name': '"Gorgui Dieng"', 'position': 'F', 'salary': 246.0},
#  {'player_name': '"Daniel Gafford"', 'position': 'C', 'salary': 272.0},
#  {'player_name': '"Amir Coffey"', 'position': 'F', 'salary': 535.0},
#  {'player_name': '"Payton Pritchard"', 'position': 'G', 'salary': 332.0},
#  {'player_name': '"Kevin Knox II"', 'position': 'F', 'salary': 342.0},
#  {'player_name': '"Rodney Hood"', 'position': 'G', 'salary': 454.0},
#  {'player_name': '"Onyeka Okongwu"', 'position': 'F', 'salary': 432.0},
#  {'player_name': '"Timothe Luwawu-Cabarrot"',
#   'position': 'G',
#   'salary': 366.0},
#  {'player_name': '"Anthony Gill"', 'position': 'F', 'salary': 533.0},
#  {'player_name': '"Corey Kispert"', 'position': 'G', 'salary': 677.0},
#  {'player_name': '"Grant Williams"', 'position': 'F', 'salary': 430.0},
#  {'player_name': '"Skylar Mays"', 'position': 'G', 'salary': 523.0},
#  {'player_name': '"Vernon Carey Jr."', 'position': 'C', 'salary': 568.0},
#  {'player_name': '"Jalen Johnson"', 'position': 'F', 'salary': 605.0},
#  {'player_name': '"Isaiah Todd"', 'position': 'F', 'salary': 678.0},
#  {'player_name': '"Kelan Martin"', 'position': 'F', 'salary': 404.0},
#  {'player_name': '"Luke Kornet"', 'position': 'C', 'salary': 408.0},
#  {'player_name': '"Aaron Nesmith"', 'position': 'G', 'salary': 438.0},
#  {'player_name': '"Semi Ojeleye"', 'position': 'F', 'salary': 483.0},
#  {'player_name': '"Malik Fitts"', 'position': 'F', 'salary': 601.0},
#  {'player_name': '"Sam Hauser"', 'position': 'F', 'salary': 607.0},
#  {'player_name': '"Brandon Boston Jr."', 'position': 'G', 'salary': 633.0},
#  {'player_name': '"Moses Wright"', 'position': 'PF', 'salary': 1500.0},
#  {'player_name': '"Jamorko Pickett"', 'position': 'SF', 'salary': 1500.0},
#  {'player_name': '"Patrick Beverley"', 'position': 'PG', 'salary': 4700.0},
#  {'player_name': '"Anthony Edwards"', 'position': 'SF', 'salary': 6600.0},
#  {'player_name': '"Naz Reid"', 'position': 'C', 'salary': 4100.0},
#  {'player_name': '"Malik Beasley"', 'position': 'SF', 'salary': 3600.0},
#  {'player_name': '"Taurean Waller-Prince"',
#   'position': 'SF',
#   'salary': 3500.0},
#  {'player_name': '"Jordan McLaughlin"', 'position': 'PG', 'salary': 3500.0},
#  {'player_name': '"Spencer Dinwiddie"', 'position': 'PG', 'salary': 12500.0},
#  {'player_name': '"Dwight Powell"', 'position': 'C', 'salary': 9000.0},
#  {'player_name': '"Austin Reaves"', 'position': 'SG', 'salary': 8500.0},
#  {'player_name': '"Dave Bertans"', 'position': 'SF', 'salary': 8000.0},
#  {'player_name': '"Maxi Kleber"', 'position': 'PF', 'salary': 11500.0},
#  {'player_name': '"Talen Horton-Tucker"', 'position': 'SG', 'salary': 11000.0},
#  {'player_name': '"Dorian Finney-Smith"', 'position': 'SF', 'salary': 9500.0},
#  {'player_name': '"Wayne Ellington"', 'position': 'SG', 'salary': 6500.0},
#  {'player_name': '"Reggie Bullock"', 'position': 'SG', 'salary': 7000.0},
#  {'player_name': '"Jalen Brunson"', 'position': 'PG', 'salary': 10500.0},
#  {'player_name': '"Kent Bazemore"', 'position': 'SF', 'salary': 6000.0},
#  {'player_name': '"Sterling Brown"', 'position': 'SG', 'salary': 6000.0},
#  {'player_name': '"Josh Green"', 'position': 'SG', 'salary': 6000.0},
#  {'player_name': '"Boban Marjanovic"', 'position': 'C', 'salary': 6000.0},
#  {'player_name': '"Moses Wright"', 'position': 'PF', 'salary': 6000.0},
#  {'player_name': '"Luka Doncic"', 'position': 'PG', 'salary': 15000.0},
#  {'player_name': '"Daniel Gafford"', 'position': 'C', 'salary': 4800.0},
#  {'player_name': '"Dwight Howard"', 'position': 'C', 'salary': 9500.0},
#  {'player_name': '"Blake Griffin"', 'position': 'PF', 'salary': 4400.0},
#  {'player_name': '"Nemanja Bjelica"', 'position': 'PF', 'salary': 4300.0},
#  {'player_name': '"James Johnson"', 'position': 'SF', 'salary': 5400.0},
#  {'player_name': '"Gary Payton II"', 'position': 'SG', 'salary': 4800.0},
#  {'player_name': '"Kelly Olynyk"', 'position': 'C', 'salary': 5000.0},
#  {'player_name': '"Kyle Kuzma"', 'position': 'SF', 'salary': 8700.0},
#  {'player_name': '"Jae\'Sean Tate"', 'position': 'SF', 'salary': 6100.0},
#  {'player_name': '"Payton Pritchard"', 'position': 'PG', 'salary': 4100.0},
#  {'player_name': '"Goran Dragic"', 'position': 'PG', 'salary': 5000.0},
#  {'player_name': '"Rodney McGruder"', 'position': 'SG', 'salary': 3600.0},
#  {'player_name': '"Nicolas Claxton"', 'position': 'C', 'salary': 4000.0},
#  {'player_name': '"Precious Achiuwa"', 'position': 'PF', 'salary': 5600.0},
#  {'player_name': '"Jalen Green"', 'position': 'SG', 'salary': 5200.0},
#  {'player_name': '"Cade Cunningham"', 'position': 'PG', 'salary': 7000.0},
#  {'player_name': '"Russell Westbrook"', 'position': 'PG', 'salary': 13500.0},
#  {'player_name': '"Nicolas Batum"', 'position': 'SF', 'salary': 4700.0},
#  {'player_name': '"Malachi Flynn"', 'position': 'PG', 'salary': 3600.0},
#  {'player_name': '"Derrick White"', 'position': 'PG', 'salary': 5500.0},
#  {'player_name': '"Pascal Siakam"', 'position': 'PF', 'salary': 8300.0},
#  {'player_name': '"Damion Lee"', 'position': 'SG', 'salary': 3800.0},
#  {'player_name': '"Josh Christopher"', 'position': 'SG', 'salary': 3500.0},
#  {'player_name': '"Semi Ojeleye"', 'position': 'SF', 'salary': 3500.0},
#  {'player_name': '"Kevin Porter"', 'position': 'SF', 'salary': 6100.0},
#  {'player_name': '"Fred Van Vleet"', 'position': 'PG', 'salary': 7500.0},
#  {'player_name': '"Chris Boucher"', 'position': 'C', 'salary': 3800.0},
#  {'player_name': '"Anthony Gill"', 'position': 'PF', 'salary': 3900.0},
#  {'player_name': '"Killian Hayes"', 'position': 'PG', 'salary': 4100.0},
#  {'player_name': '"D\'Angelo Russell"', 'position': 'SG', 'salary': 7800.0},
#  {'player_name': '"Garrison Mathews"', 'position': 'SF', 'salary': 4200.0},
#  {'player_name': '"Marcus Morris"', 'position': 'PF', 'salary': 5800.0},
#  {'player_name': '"Alperen Sengun"', 'position': 'C', 'salary': 4300.0},
#  {'player_name': '"Thomas Bryant"', 'position': 'C', 'salary': 4400.0},
#  {'player_name': '"Trevor Ariza"', 'position': 'PF', 'salary': 7500.0},
#  {'player_name': '"LaMarcus Aldridge"', 'position': 'C', 'salary': 4600.0},
#  {'player_name': '"Gary Trent"', 'position': 'SG', 'salary': 6500.0},
#  {'player_name': '"Dennis Schroder"', 'position': 'PG', 'salary': 5500.0},
#  {'player_name': '"Jordan Poole"', 'position': 'PG', 'salary': 5000.0},
#  {'player_name': '"Cameron Thomas"', 'position': 'SG', 'salary': 5000.0},
#  {'player_name': '"Delon Wright"', 'position': 'PG', 'salary': 3500.0},
#  {'player_name': '"Khem Birch"', 'position': 'C', 'salary': 3500.0},
#  {'player_name': '"Jayson Tatum"', 'position': 'SF', 'salary': 8900.0},
#  {'player_name': '"Grant Williams"', 'position': 'PF', 'salary': 3700.0},
#  {'player_name': '"Cory Joseph"', 'position': 'PG', 'salary': 3700.0},
#  {'player_name': '"Seth Curry"', 'position': 'PG', 'salary': 6200.0},
#  {'player_name': '"Thaddeus Young"', 'position': 'PF', 'salary': 3800.0},
#  {'player_name': '"Eric Gordon"', 'position': 'SF', 'salary': 3900.0},
#  {'player_name': '"Deni Avdija"', 'position': 'SF', 'salary': 5900.0},
#  {'player_name': '"Otto Porter"', 'position': 'SF', 'salary': 4000.0},
#  {'player_name': '"Rui Hachimura"', 'position': 'SF', 'salary': 4200.0},
#  {'player_name': '"Saddiq Bey"', 'position': 'SF', 'salary': 6300.0},
#  {'player_name': '"Patrick Mills"', 'position': 'SG', 'salary': 4600.0},
#  {'player_name': '"Corey Kispert"', 'position': 'SF', 'salary': 4300.0},
#  {'player_name': '"Stephen Curry"', 'position': 'PG', 'salary': 9700.0},
#  {'player_name': '"De\'Andre Hunter"', 'position': 'SF', 'salary': 4600.0},
#  {'player_name': '"Jaden McDaniels"', 'position': 'PF', 'salary': 4700.0},
#  {'player_name': '"Christian Wood"', 'position': 'PF', 'salary': 7200.0},
#  {'player_name': '"Robert Covington"', 'position': 'PF', 'salary': 4800.0},
#  {'player_name': '"Ishmael Smith"', 'position': 'PG', 'salary': 4800.0},
#  {'player_name': '"Jaylen Brown"', 'position': 'SF', 'salary': 8000.0},
#  {'player_name': '"Kevin Huerter"', 'position': 'SG', 'salary': 4900.0},
#  {'player_name': '"Raul Neto"', 'position': 'PG', 'salary': 5200.0},
#  {'player_name': '"Isaiah Stewart"', 'position': 'PF', 'salary': 5200.0},
#  {'player_name': '"Jonathan Kuminga"', 'position': 'SF', 'salary': 5200.0},
#  {'player_name': '"Scottie Barnes"', 'position': 'SF', 'salary': 5500.0},
#  {'player_name': '"Terance Mann"', 'position': 'SG', 'salary': 6100.0},
#  {'player_name': '"Bruce Brown"', 'position': 'SG', 'salary': 5700.0},
#  {'player_name': '"Trae Young"', 'position': 'PG', 'salary': 9500.0},
#  {'player_name': '"Ivica Zubac"', 'position': 'C', 'salary': 5800.0},
#  {'player_name': '"Jerami Grant"', 'position': 'PF', 'salary': 5900.0},
#  {'player_name': '"Al Horford"', 'position': 'PF', 'salary': 6500.0},
#  {'player_name': '"Bogdan Bogdanovic"', 'position': 'SF', 'salary': 6700.0},
#  {'player_name': '"Reggie Jackson"', 'position': 'PG', 'salary': 7000.0},
#  {'player_name': '"Robert Williams"', 'position': 'PF', 'salary': 7700.0},
#  {'player_name': '"Amir Coffey"', 'position': 'SF', 'salary': 3800.0},
#  {'player_name': '"Kessler Edwards"', 'position': 'SF', 'salary': 3800.0},
#  {'player_name': '"Onyeka Okongwu"', 'position': 'C', 'salary': 4300.0},
#  {'player_name': '"Kentavious Caldwell-Pope"',
#   'position': 'SG',
#   'salary': 4400.0},
#  {'player_name': '"Jarred Vanderbilt"', 'position': 'PF', 'salary': 4200.0},
#  {'player_name': '"Luke Kennard"', 'position': 'SG', 'salary': 4600.0},
#  {'player_name': '"Karl-Anthony Towns"', 'position': 'C', 'salary': 9300.0},
#  {'player_name': '"Kevon Looney"', 'position': 'C', 'salary': 4700.0},
#  {'player_name': '"Danilo Gallinari"', 'position': 'SF', 'salary': 4900.0},
#  {'player_name': '"Andrew Wiggins"', 'position': 'SF', 'salary': 5500.0},
#  {'player_name': '"Marcus Smart"', 'position': 'SG', 'salary': 6200.0},
#  {'player_name': '"Clint Capela"', 'position': 'C', 'salary': 6600.0},
#  {'player_name': '"Andre Drummond"', 'position': 'C', 'salary': 6700.0},
#  {'player_name': '"Gorgui Dieng"', 'position': 'C', 'salary': 3500.0},
#  {'player_name': '"Aaron Nesmith"', 'position': 'SG', 'salary': 3500.0},
#  {'player_name': '"Jalen Johnson"', 'position': 'SF', 'salary': 3500.0},
#  {'player_name': '"David Nwaba"', 'position': 'SF', 'salary': 3500.0},
#  {'player_name': '"Frank Jackson"', 'position': 'PG', 'salary': 3500.0},
#  {'player_name': '"Carmelo Anthony"', 'position': 'SF', 'salary': 10500.0},
#  {'player_name': '"LeBron James"', 'position': 'SF', 'salary': 15500.0},
#  {'player_name': '"Malik Monk"', 'position': 'SG', 'salary': 10000.0},
#  {'player_name': '"Juan Toscano-Anderson"',
#   'position': 'SF',
#   'salary': 3500.0},
#  {'player_name': '"Josh Okogie"', 'position': 'SF', 'salary': 3500.0},
#  {'player_name': '"Jaylen Nowell"', 'position': 'PG', 'salary': 3500.0},
#  {'player_name': '"Sviatoslav Mykhailiuk"',
#   'position': 'SG',
#   'salary': 3500.0},
#  {'player_name': '"Yuta Watanabe"', 'position': 'SG', 'salary': 3500.0},
#  {'player_name': '"Luke Kornet"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"Kelan Martin"', 'position': 'SF', 'salary': 3500.0},
#  {'player_name': '"Timothe Luwawu"', 'position': 'SF', 'salary': 3500.0},
#  {'player_name': '"Sam Hauser"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"Malik Fitts"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"Skylar Mays"', 'position': 'SG', 'salary': 3500.0},
#  {'player_name': '"Daniel Theis"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"Kevin Knox"', 'position': 'SF', 'salary': 3500.0},
#  {'player_name': '"Jake Layman"', 'position': 'SF', 'salary': 3500.0},
#  {'player_name': '"Chris Chiozza"', 'position': 'PG', 'salary': 3500.0},
#  {'player_name': '"Nathan Knight"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"Rodney Hood"', 'position': 'SG', 'salary': 3500.0},
#  {'player_name': '"Isaiah Hartenstein"', 'position': 'PF', 'salary': 5800.0},
#  {'player_name': '"Bruno Fernando"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"Marvin Bagley"', 'position': 'PF', 'salary': 4200.0},
#  {'player_name': '"Vernon Carey"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"Stanley Johnson"', 'position': 'SF', 'salary': 7000.0},
#  {'player_name': '"Tomas Satoransky"', 'position': 'PG', 'salary': 3500.0},
#  {'player_name': '"David Duke"', 'position': 'SG', 'salary': 3500.0},
#  {'player_name': '"Dalano Banton"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"Justin Champagnie"', 'position': 'SF', 'salary': 3500.0},
#  {'player_name': '"Day\'Ron Sharpe"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"Isaiah Livers"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"Luka Garza"', 'position': 'C', 'salary': 3500.0},
#  {'player_name': '"Chris Smith"', 'position': 'PF', 'salary': 3500.0},
#  {'player_name': '"Saben Lee"', 'position': 'PG', 'salary': 3500.0},
#  {'player_name': '"Jamorko Pickett"', 'position': 'SF', 'salary': 3500.0},
#  {'player_name': '"Quinndary Weatherspoon"',
#   'position': 'SG',
#   'salary': 3500.0},
#  {'player_name': '"Isaiah Todd"', 'position': 'PF', 'salary': 3500.0}]

# %%
import pickle

# Pickle
# with open('positions_and_salary.pkl', 'wb') as f:
#     pickle.dump(position_and_salary, f)

# Unpickle
# with open('positions_and_salary.pkl', 'rb') as f:
    # position_and_salary = pickle.load(f)
