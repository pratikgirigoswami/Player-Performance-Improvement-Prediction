# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import pandas as pd 
df = pd.read_pickle('dataNew.pkl')
df.describe()
# Out:
#                Home           Won  Minutes played  Field Goals Made  \
# count  21349.000000  21349.000000    21349.000000      21349.000000
# mean       0.499930      0.508267       23.362406          4.045482
# std        0.500012      0.499943       10.344631          3.232474
# min        0.000000      0.000000        0.000000          0.000000
# 25%        0.000000      0.000000       16.000000          2.000000
# 50%        0.000000      1.000000       24.000000          3.000000
# 75%        1.000000      1.000000       32.000000          6.000000
# max        1.000000      1.000000       51.000000         21.000000
#
#        Field Goals Attempted  Field Goals 3 Points Made  \
# count           21349.000000               21349.000000
# mean                8.641716                   1.238653
# std                 5.957309                   1.523488
# min                 0.000000                   0.000000
# 25%                 4.000000                   0.000000
# ...

# %% [markdown]
# Dataframe

# %%
df
# Out:
#       Season ID Player ID       Player Name     Game ID  Game Date  \
# 0         22020   1630173  Precious Achiuwa  0022001069 2021-05-16
# 1         22020   1630173  Precious Achiuwa  0022001062 2021-05-15
# 2         22020   1630173  Precious Achiuwa  0022001050 2021-05-13
# 3         22020   1630173  Precious Achiuwa  0022000986 2021-05-04
# 4         22020   1630173  Precious Achiuwa  0022000969 2021-05-02
# ...         ...       ...               ...         ...        ...
# 21344     22020   1627826       Ivica Zubac  0022000061 2020-12-30
# 21345     22020   1627826       Ivica Zubac  0022000054 2020-12-29
# 21346     22020   1627826       Ivica Zubac  0022000031 2020-12-27
# 21347     22020   1627826       Ivica Zubac  0022000009 2020-12-25
# 21348     22020   1627826       Ivica Zubac  0022000002 2020-12-22
#
#            Matchup Player Team Opponent  Home  Won  ...  Free Throws Attempt  \
# 0        MIA @ DET         MIA      DET     0    1  ...                    7
# ...

# %%
df.head()
# Out:
#   Season ID Player ID       Player Name     Game ID  Game Date      Matchup  \
# 0     22020   1630173  Precious Achiuwa  0022001069 2021-05-16    MIA @ DET
# 1     22020   1630173  Precious Achiuwa  0022001062 2021-05-15    MIA @ MIL
# 2     22020   1630173  Precious Achiuwa  0022001050 2021-05-13  MIA vs. PHI
# 3     22020   1630173  Precious Achiuwa  0022000986 2021-05-04  MIA vs. DAL
# 4     22020   1630173  Precious Achiuwa  0022000969 2021-05-02    MIA @ CHA
#
#   Player Team Opponent  Home  Won  ...  Free Throws Attempt  \
# 0         MIA      DET     0    1  ...                    7
# 1         MIA      MIL     0    0  ...                    0
# 2         MIA      PHI     1    1  ...                    0
# 3         MIA      DAL     1    0  ...                    0
# 4         MIA      CHA     0    1  ...                    0
#
#    Offensive Rebounds  Defensive Rebounds  Assists  Steals  Blocks  Turnovers  \
# ...

# %%
df.tail()
# Out:
#       Season ID Player ID  Player Name     Game ID  Game Date      Matchup  \
# 21344     22020   1627826  Ivica Zubac  0022000061 2020-12-30  LAC vs. POR
# 21345     22020   1627826  Ivica Zubac  0022000054 2020-12-29  LAC vs. MIN
# 21346     22020   1627826  Ivica Zubac  0022000031 2020-12-27  LAC vs. DAL
# 21347     22020   1627826  Ivica Zubac  0022000009 2020-12-25    LAC @ DEN
# 21348     22020   1627826  Ivica Zubac  0022000002 2020-12-22    LAC @ LAL
#
#       Player Team Opponent  Home  Won  ...  Free Throws Attempt  \
# 21344         LAC      POR     1    1  ...                    4
# 21345         LAC      MIN     1    1  ...                    2
# 21346         LAC      DAL     1    0  ...                    4
# 21347         LAC      DEN     0    1  ...                   11
# 21348         LAC      LAL     0    1  ...                    4
#
#        Offensive Rebounds  Defensive Rebounds  Assists  Steals  Blocks  \
# ...

# %% [markdown]
# # CHECKING FOR NULL VALUES ('?') IN THE RESPECTIVE COLUMNS

# %%
df.isin(['?']).sum(axis=0)
# Out:
# Season ID                      0
# Player ID                      0
# Player Name                    0
# Game ID                        0
# Game Date                      0
# Matchup                        0
# Player Team                    0
# Opponent                       0
# Home                           0
# Won                            0
# Minutes played                 0
# Field Goals Made               0
# Field Goals Attempted          0
# Field Goals 3 Points Made      0
# Field Goal 3 Points Attempt    0
# Free Throws Made               0
# Free Throws Attempt            0
# Offensive Rebounds             0
# Defensive Rebounds             0
# Assists                        0
# Steals                         0
# Blocks                         0
# Turnovers                      0
# Personal Fouls                 0
# Points                         0
# Player Efficiency Ratings      0
# dtype: int64

# %%
df.isin(['?']).sum()
# Out:
# Season ID                      0
# Player ID                      0
# Player Name                    0
# Game ID                        0
# Game Date                      0
# Matchup                        0
# Player Team                    0
# Opponent                       0
# Home                           0
# Won                            0
# Minutes played                 0
# Field Goals Made               0
# Field Goals Attempted          0
# Field Goals 3 Points Made      0
# Field Goal 3 Points Attempt    0
# Free Throws Made               0
# Free Throws Attempt            0
# Offensive Rebounds             0
# Defensive Rebounds             0
# Assists                        0
# Steals                         0
# Blocks                         0
# Turnovers                      0
# Personal Fouls                 0
# Points                         0
# Player Efficiency Ratings      0
# dtype: int64

# %% [markdown]
# # creating a dataframe with numerical values

# %%
numerical_columns = df[['Season ID','Player ID','Game ID','Game Date','Home','Won','Minutes played','Field Goals Made','Field Goals Attempted','Field Goals 3 Points Made','Field Goal 3 Points Attempt','Free Throws Made','Free Throws Attempt','Offensive Rebounds','Defensive Rebounds','Assists','Steals','Blocks','Turnovers','Personal Fouls','Points']]

# %% [markdown]
# # creating a dataframe with categorical values

# %%
catagorical_columns = df[['Player Name','Matchup','Player Team','Opponent']]

# %%
plt.figure(figsize = (16,16))
sb.heatmap(numerical_columns.corr(), annot=True)
plt.title('Heatmap Of Numerical Columns', fontsize=25, fontweight='bold')
plt.show()

# %% [markdown]
# # Player names with number of games they played

# %%
df1 = pd.DataFrame(df, columns= ['Player Name','Player Team'])

player_names_count = df1.pivot_table(columns=['Player Name'], aggfunc='size')
player_names_count
# Out:
# Player Name
# Aaron Gordon          50
# Aaron Holiday         66
# Aaron Nesmith         46
# Abdel Nader           24
# Al Horford            28
#                       ..
# Xavier Tillman Sr.    59
# Yuta Watanabe         50
# Zach LaVine           58
# Zeke Nnaji            42
# Zion Williamson       61
# Length: 453, dtype: int64

# %% [markdown]
# # Maximum, minimum and mean number of games played by a player

# %%
player_names_count.describe()
# Out:
# count    453.000000
# mean      47.128035
# std       18.369762
# min        1.000000
# 25%       35.000000
# 50%       51.000000
# 75%       63.000000
# max       72.000000
# dtype: float64

# %% [markdown]
# #

# %%
df2 = pd.DataFrame(df, columns= ['Game ID','Player Team'])

Game_ID_count = df2.pivot_table(columns=['Game ID'], aggfunc='size')
Game_ID_count
# Out:
# Game ID
# 0022000001    25
# 0022000002    23
# 0022000003    19
# 0022000004    22
# 0022000005    18
#               ..
# 0022001076    26
# 0022001077    22
# 0022001078    20
# 0022001079    13
# 0022001080    19
# Length: 1080, dtype: int64

# %% [markdown]
# #

# %%
df3 = pd.DataFrame(df, columns= ['Game Date','Player Team'])

Game_Date_count = df3.pivot_table(columns=['Game Date'], aggfunc='size')
Game_Date_count
# Out:
# Game Date
# 2020-12-22     48
# 2020-12-23    245
# 2020-12-25    118
# 2020-12-26    199
# 2020-12-27    211
#              ...
# 2021-05-12    121
# 2021-05-13    176
# 2021-05-14    141
# 2021-05-15    125
# 2021-05-16    271
# Length: 140, dtype: int64

# %%
df4 = pd.DataFrame(df, columns= ['Matchup'])

Matchup_count = df4.pivot_table(columns=['Matchup'], aggfunc='size')
Matchup_count
# Out:
# Matchup
# ATL @ BKN      22
# ATL @ BOS      20
# ATL @ CHA      17
# ATL @ CHI      11
# ATL @ CLE      10
#                ..
# WAS vs. POR    12
# WAS vs. SAC     9
# WAS vs. SAS    10
# WAS vs. TOR    12
# WAS vs. UTA    10
# Length: 1740, dtype: int64

# %%
df5 = pd.DataFrame(df, columns= ['Player Team'])

Player_Team_count = df5.pivot_table(columns=['Player Team'], aggfunc='size')
Player_Team_count
# Out:
# Player Team
# ATL    724
# BKN    675
# BOS    715
# CHA    635
# CHI    727
# CLE    651
# DAL    763
# DEN    809
# DET    763
# GSW    693
# HOU    602
# IND    706
# LAC    779
# LAL    616
# MEM    757
# MIA    735
# MIL    748
# MIN    749
# NOP    656
# NYK    749
# OKC    635
# ORL    586
# PHI    714
# PHX    779
# POR    723
# SAC    658
# SAS    769
# TOR    675
# UTA    775
# WAS    783
# dtype: int64

# %%
plt.figure(figsize=(30,14))
sb.countplot(x=df['Player Team'], hue=df['Field Goals Made'], palette='Set1')
plt.legend(loc='upper right')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Field Goals Made by 30 teams', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(25,14))
sb.countplot(x=df['Player Team'], hue=df['Field Goals Attempted'], palette='Set1')
plt.legend(loc='upper right')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Field Goals Attempted by 30 teams', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(30,19))
sb.countplot(x=df['Player Team'], hue=df['Field Goals 3 Points Made'], palette='Set1')
plt.legend(loc='upper right')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Field Goals 3 Points Made by 30 teams', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(30,19))
sb.countplot(x=df['Player Team'], hue=df['Field Goal 3 Points Attempt'], palette='Set1')
plt.legend(loc='upper right')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Field Goal 3 Points Attempts by 30 teams', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(30,19))
sb.countplot(x=df['Player Team'], hue=df['Free Throws Made'], palette='Set1')
plt.legend(loc='upper right')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Free Throws Made by 30 teams', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(30,19))
sb.countplot(x=df['Player Team'], hue=df['Free Throws Attempt'], palette='Set1')
plt.legend(loc='upper right')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Free Throws Attempt by 30 teams', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(30,19))
sb.countplot(x=df['Player Team'], hue=df['Offensive Rebounds'], palette='Set1')
plt.legend(loc='upper right')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Offensive Rebounds by 30 teams', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(30,19))
sb.countplot(x=df['Player Team'], hue=df['Defensive Rebounds'], palette='Set1')
plt.legend(loc='upper right')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Defensive Rebounds by 30 teams', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(100,19))
sb.countplot(x=df['Player Team'], hue=df['Assists'], palette='Set1')
plt.legend(loc='upper left')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Assists by 30 teams', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(30,19))
sb.countplot(x=df['Player Team'], hue=df['Steals'], palette='Set1')
plt.legend(loc='upper right')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Steals by 30 teams', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(30,19))
sb.countplot(x=df['Player Team'], hue=df['Blocks'], palette='Set1')
plt.legend(loc='upper right')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Blocks by 30 teams', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(30,19))
sb.countplot(x=df['Player Team'], hue=df['Turnovers'], palette='Set1')
plt.legend(loc='upper right')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Turnovers by 30 teams', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(30,19))
sb.countplot(x=df['Player Team'], hue=df['Personal Fouls'], palette='Set1')
plt.legend(loc='upper right')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Personal Fouls by 30 teams', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(30,19))
sb.countplot(x=df['Player Team'], hue=df['Points'], palette='Set1')
plt.legend(loc='upper right')
plt.ylabel('Count', fontsize=15, fontweight='bold')
plt.xlabel('Player Team', fontsize=15, fontweight='bold')
plt.title('Comparing Points by 30 teams', fontsize=15, fontweight='bold')
plt.show()
